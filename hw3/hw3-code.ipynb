# %% [markdown]
# # Deep Learning: Assignment #3
# ## Submission date: 07/01/2026, 23:59.
# ### Topics:
# - RNNs
# - GRUs
# - LSTMs
# - Transformers

# %% [markdown]
# **Submitted by:**
#
# - **Yosef Asadi**
# - **Aisha Abu Dahesh**

# %% [markdown]
# **Assignment Instructions:**
#
# · Submissions are in **pairs only**. Write both names + IDs at the top of the notebook.
#
# · Keep your code **clean, concise, and readable**.
#
# · You may work in your IDE, but you **must** paste the final code back into the **matching notebook cells** and run it there.
#
#
# · <font color='red'>Write your textual answers in red.</font>
# (e.g., `<span style="color:red">your answer here</span>`)
#
# · All figures, printed results, and outputs should remain visible in the notebook.
# Run **all cells** before submitting and **do not clear outputs**.
#
# · Use relative paths — **no absolute file paths** pointing to local machines.
#
# · **Important:** Your submission must be entirely your own.
# Any form of plagiarism (including uncredited use of ChatGPT or AI tools) will result in **grade 0** and disciplinary action.

# %% [markdown]
# ## Question 1 — Chatbot Tutorial (35 Points)
#
# In this tutorial, we explore a classical and instructive application of
# **recurrent sequence-to-sequence (seq2seq) models**: building a neural
# chatbot. Chatbots provide a natural and intuitive testbed for studying
# sequence models, as they require processing variable-length input
# sequences and generating coherent variable-length outputs, one token at
# a time.
#
# Conversational agents are a long-standing and active research topic in
# artificial intelligence. Chatbots appear in a wide range of practical
# settings, including customer service systems, online helpdesks, and
# virtual assistants. Many deployed systems rely on **retrieval-based
# models**, which select responses from a predefined set based on the input
# query. While such approaches can be effective in narrowly defined
# domains, they lack the flexibility required for open-domain
# conversation.
#
# Teaching a machine to generate meaningful, context-aware responses
# across multiple domains remains a challenging and largely unsolved
# problem. The rise of deep learning has enabled a class of **generative
# conversational models**, most notably the *Neural Conversational Model*
# introduced by Vinyals and Le (2015), which demonstrated that an
# encoder–decoder architecture can be trained end-to-end to map input
# sentences directly to output sentences.
#
# Inspired by this line of work, we study a simplified generative chatbot
# implemented using modern deep learning tools.
#
# In this question, we will work with conversational data extracted from
# movie scripts in the
# [Cornell Movie-Dialogs Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html).
# Each training example consists of an input sentence and a corresponding
# response sentence, forming a paired sequence-to-sequence learning task.

# %% [markdown]
# ### Load & Preprocess Data

# %% [markdown]
# To start, we load the data. Download the data ZIP file
# [here](https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip) and unzip it in the current directory, or alternalively run the following cell:

# %%
# !mkdir data
# !cd data
# !wget https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip
# !unzip -q movie-corpus.zip
# !cd ..
# Out:
# mkdir: cannot create directory ‘data’: File exists
# --2026-01-16 16:41:42--  https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip
# Resolving zissou.infosci.cornell.edu (zissou.infosci.cornell.edu)... 128.253.51.179
# Connecting to zissou.infosci.cornell.edu (zissou.infosci.cornell.edu)|128.253.51.179|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40854701 (39M) [application/zip]
# Saving to: ‘movie-corpus.zip.3’
#
# movie-corpus.zip.3  100%[===================>]  38.96M  14.4MB/s    in 2.7s
#
# 2026-01-16 16:41:45 (14.4 MB/s) - ‘movie-corpus.zip.3’ saved [40854701/40854701]
#
# replace movie-corpus/utterances.jsonl? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %% [markdown]
# After loading the data, let’s import some necessities.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)_
# is a rich dataset of movie character dialog:
#
# -  220,579 conversational exchanges between 10,292 pairs of movie
#    characters
# -  9,035 characters from 617 movies
# -  304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we’ll take a look at some lines of our datafile to see the
# original format.

# %%
# !ls data
# Out:
# save

# %%
corpus = "movie-corpus"
corpus_name = "movie-corpus"

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "utterances.jsonl"))
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'

# %% [markdown]
# #### Create formatted data file

# %% [markdown]
# For convenience, we'll create a nicely formatted data file in which each line contains a tab-separated *query sentence* and a *response sentence* pair.
#
# The following functions facilitate the parsing of the raw
# *utterances.jsonl* data file.
#
#
# In the next cell, you'll find the functions:
# -  ``loadLinesAndConversations`` splits each line of the file into a dictionary of lines with fields: lineID, characterID, and text and then groups them into conversations with fields: conversationID, movieID, and lines.
#
# -  ``extractSentencePairs`` extracts pairs of sentences from
#    conversations.
#
#
# > Run the code in the next cell.

# %%
# Splits each line of the file to create lines and conversations
def loadLinesAndConversations(fileName):
    lines = {}
    conversations = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            # Extract fields for line object
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj

            # Extract fields for conversation object
            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj

    return lines, conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations.values():
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we’ll call these functions and create the file. We’ll call it
# *formatted_movie_lines.txt*.

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict and conversations dict
lines = {}
conversations = {}
# Load lines and conversations
print("\nProcessing corpus into lines and conversations...")
lines, conversations = loadLinesAndConversations(os.path.join(corpus, "utterances.jsonl"))

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"

# %% [markdown]
# #### Trim Data

# %% [markdown]
# We now move from raw text to a representation that a neural network can process.
# Our next task is to build a **vocabulary** and load the **query/response pairs**
# into memory.
#
# Unlike images, text does not come with an inherent mapping to a numerical space.
# A sequence model expects **integer token indices**, so we must define a mapping
# from each unique word in the dataset to a discrete index.
#
# To do this, we define a `Voc` (vocabulary) class that maintains:
#
# - `word2index`: a mapping from each word to an integer index
# - `index2word`: the inverse mapping from indices back to words
# - `word2count`: a frequency table used for trimming rare words
# - `num_words`: the current vocabulary size
#
# In addition, we reserve a small set of **special tokens**:
#
# - `PAD` for padding shorter sequences in a batch
# - `SOS` to mark the start of a sequence for the decoder
# - `EOS` to mark the end of a sequence
# - `UNK` to represent words that are not in the vocabulary
#
# Later, we will remove infrequent words from the vocabulary using a minimum
# frequency threshold (`MIN_COUNT`). This reduces noise and decreases the effective
# problem size, which often improves training stability and convergence.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token
UNK_token = 3  # Unknown word token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {
            PAD_token: "PAD",
            SOS_token: "SOS",
            EOS_token: "EOS",
            UNK_token: "UNK",
        }
        self.num_words = 4  # Count default tokens

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []
        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {
            PAD_token: "PAD",
            SOS_token: "SOS",
            EOS_token: "EOS",
            UNK_token: "UNK",
        }
        self.num_words = 4  # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# We begin by converting Unicode strings to ASCII using `unicodeToAscii`.
# Next, all text is lowercased and non-letter characters are removed while
# preserving basic punctuation (`normalizeString`).
# Finally, to promote stable training and reduce unnecessary computation,
# we filter out sentence pairs whose length exceeds the `MAX_LENGTH`
# threshold (`filterPairs`).

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

def readVocs(datafile, corpus_name):
    print("Reading lines...")
    lines = open(datafile, encoding='utf-8').read().strip().split('\n')
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs

save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)

print("\nSample pairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18083
#
# Sample pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']

# %% [markdown]
# Another technique that often improves training efficiency is **trimming
# rarely used words** from the vocabulary. Intuitively, words that appear
# only a handful of times contribute little to the learning signal, while
# significantly increasing the size of the vocabulary.
#
# We perform trimming as a two-step process:
#
# 1. Remove words that appear fewer than `MIN_COUNT` times from the
#    vocabulary.
# 2. Remove sentence pairs that contain any of the trimmed words, ensuring
#    that all remaining training examples are fully represented in the
#    vocabulary.
#
# This procedure reduces noise, lowers the dimensionality of the problem,
# and often leads to faster and more stable convergence during training.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(
        len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)
    ))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total

# %% [markdown]
# ### Preparing Data for the Model

# %% [markdown]
# So far, we have transformed raw conversational text into a cleaned and
# trimmed set of *(input, response)* sentence pairs, along with a vocabulary
# that maps words to integer indices.
#
# However, neural sequence models do not operate directly on text. Instead,
# they expect **numerical tensors** as input. In this section, we convert
# our sentence pairs into padded tensors that can be efficiently processed
# by the encoder–decoder model.
#
# To accelerate training and make effective use of GPU parallelism, we will
# train the model using **mini-batches** rather than individual sentence
# pairs. This introduces an additional challenge: sentences within a batch
# may have different lengths.
#
# To handle variable-length sequences, we adopt the following conventions:
#
# - Sentences are converted to sequences of word indices and terminated
#   with an `EOS_token`.
# - All sequences in a batch are padded to the length of the longest
#   sequence using the `PAD_token`.
# - Batched input tensors are shaped as
#   **(max_sequence_length, batch_size)**,
#   so that each time step can be processed across all sequences in parallel.
#
# This layout is particularly convenient for recurrent models, which
# process input one time step at a time.

# %% [markdown]
# In addition to the padded input and target tensors, we also construct:
#
# - A **lengths tensor**, which stores the true (unpadded) length of each
#   input sequence. This will later be used to efficiently process variable-
#   length sequences.
# - A **binary mask tensor** for the target sequences, where padded positions
#   are marked with 0 and valid tokens with 1. This allows us to ignore padded
#   values when computing the training loss.
#
# The following helper functions implement this batching pipeline.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index.get(word, UNK_token) for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))


def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m


# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths


# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max(len(indexes) for indexes in indexes_batch)
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len


# Returns all items for a given batch of sentence pairs
def batch2TrainData(voc, pair_batch):
    # Sort pairs by input sentence length (descending)
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)

    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])

    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# #### Sequence-to-Sequence Architecture
#
# The core of our chatbot is a **sequence-to-sequence (seq2seq)** model.
# The objective of a seq2seq model is to map a variable-length input
# sequence to a variable-length output sequence using a fixed-size neural
# network.
#
# [Sutskever et al. (2014)](https://arxiv.org/abs/1409.3215) demonstrated
# that this task can be accomplished by composing two recurrent neural
# networks:
#
# - An **encoder**, which processes the input sequence and compresses it
#   into an internal representation.
# - A **decoder**, which generates the output sequence one token at a time,
#   conditioned on the encoder’s representation.
#
# In the context of conversational modeling, the encoder reads the input
# sentence (the query), and the decoder generates the response.
#
# This encoder–decoder formulation underlies many modern sequence modeling
# approaches in machine translation, dialogue systems, and text
# generation.

# %% [markdown]
# #### Encoder
#
# In this part, you will implement the **encoder** component of the
# sequence-to-sequence model.
#
# The encoder processes the input sentence one token (word) at a time.
# At each time step, it produces an output vector and updates an internal
# **hidden state** that summarizes the sequence observed so far.
#
# You should implement the encoder using a **multi-layer Gated Recurrent
# Unit (GRU)**, introduced by [Cho et al. (2014)](https://arxiv.org/pdf/1406.1078v3.pdf).
# GRUs extend standard recurrent neural networks by incorporating gating
# mechanisms that regulate information flow, enabling more effective
# modeling of long-term dependencies.
#
# Your encoder should be **bidirectional**, meaning that the input sequence is processed both forward and backward in time. The outputs of the forward and backward GRUs should be **summed** at each time step to form the final encoder output representation.
#
# Before being passed to the GRU, word indices are mapped into a continuous vector space using an **embedding layer**, which is provided to the encoder. The embedding dimension is equal to the GRU hidden size.
#
# When processing padded mini-batches, you must correctly pack and unpack
# sequences using:
#
# - `nn.utils.rnn.pack_padded_sequence`
# - `nn.utils.rnn.pad_packed_sequence`
#
# This ensures that the GRU does not perform unnecessary computation over
# padding tokens.

# %% [markdown]
# **Encoder Inputs**
#
# - `input_seq`: Padded batch of input sentences
#   Shape: *(max_length, batch_size)*
#
# - `input_lengths`: True lengths of each sentence in the batch
#   Shape: *(batch_size)*
#
# **Encoder Outputs**
#
# - `outputs`: Output features from the last hidden layer of the GRU
#   (sum of bidirectional outputs)
#   Shape: *(max_length, batch_size, hidden_size)*
#
# - `hidden`: Final hidden state of the GRU
#   Shape: *(n_layers × num_directions, batch_size, hidden_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        # TODO: Implement
        super().__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.embedding = embedding

        self.gru = nn.GRU(
            input_size=hidden_size,
            hidden_size=hidden_size,
            num_layers=n_layers,
            dropout=(0 if n_layers == 1 else dropout),
            bidirectional=True
        )
    def forward(self, input_seq, input_lengths, hidden=None):
        # TODO: Implement
        embedded = self.embedding(input_seq)

        packed = torch.nn.utils.rnn.pack_padded_sequence(
            embedded, input_lengths.cpu(), enforce_sorted=False
        )

        outputs, hidden = self.gru(packed, hidden)

        outputs, _ = torch.nn.utils.rnn.pad_packed_sequence(outputs)

        outputs = outputs[:, :, :self.hidden_size] + outputs[:, :, self.hidden_size:]
        return outputs, hidden

# %% [markdown]
# #### Decoder with Attention
#
# The decoder generates the response sequence in a token-by-token manner.
# At each time step, it predicts the next word based on:
#
# - its current hidden state,
# - the previously generated word, and
# - a **context vector** computed from the encoder outputs.
#
# A limitation of vanilla seq2seq models is their reliance on a single
# fixed-length context vector to represent the entire input sequence.
# This bottleneck becomes particularly problematic for long input
# sentences.
#
# To address this issue, [Bahdanau et al. (2015)](https://arxiv.org/abs/1409.0473) introduced the **attention mechanism**, which allows the decoder to focus on different parts of the input sequence at each decoding step.
#
# [Luong et al. (2015)](https://arxiv.org/abs/1508.04025) later proposed
# **Global Attention**, in which the decoder attends to *all* encoder
# hidden states at every time step. Attention weights are computed using
# the decoder’s current hidden state and the encoder outputs via a
# parameterized **score function**.
#
# In this assignment, you will implement Luong-style global attention., which computes a soft alignment between the decoder state and the encoder outputs, producing a context vector that guides each decoding step.

# %% [markdown]
# At a given decoding step $t$, the attention mechanism computes an
# alignment score between the current decoder hidden state $h_t$ and each encoder output $\bar{h_s}$.
#
# Luong attention defines three possible **score functions**:
#
# - **Dot**:
#   $\text{score}(h_t, \bar{h}_s) = h_t^\top \bar{h}_s$
#
# - **General**:
#   $\text{score}(h_t, \bar{h}_s) = h_t^\top W \bar{h}_s$
#
# - **Concat**:
#   $\text{score}(h_t, \bar{h}_s) = v^\top \tanh(W [h_t ; \bar{h}_s])$
#
# The attention weights are obtained by applying a softmax over all encoder time steps. These weights are then used to compute a **context vector** as a weighted sum of encoder outputs.

# %%
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super().__init__()
        # TODO: validate method
        # TODO: define parameters for the chosen attention method
        self.method = method
        self.hidden_size = hidden_size
        if self.method not in ["dot", "general", "concat"]:
          raise ValueError(f"{self.method} is not a valid attention method")

        # Learnable parameters depend on the method
        if self.method == "general":
            self.attn = nn.Linear(hidden_size, hidden_size)

        elif self.method == "concat":
            self.attn = nn.Linear(hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_outputs):
        return torch.sum(hidden * encoder_outputs, dim=2)

    def general_score(self, hidden, encoder_outputs):
        energy = self.attn(encoder_outputs)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_outputs):

        T = encoder_outputs.size(0)
        hidden_expanded = hidden.expand(T, -1, -1)
        energy = torch.tanh(self.attn(torch.cat((hidden_expanded, encoder_outputs), dim=2)))
        return torch.sum(self.v * energy, dim=2)


    def forward(self, hidden, encoder_outputs):
        # TODO: compute attention energies
        # TODO: normalize with softmax
        # TODO: return attention weights of shape (batch_size, 1, max_length)
        if self.method == "dot":
            attn_energies = self.dot_score(hidden, encoder_outputs)
        elif self.method == "general":
            attn_energies = self.general_score(hidden, encoder_outputs)
        else :
            attn_energies = self.concat_score(hidden, encoder_outputs)

        attn_energies = attn_energies.transpose(0, 1)

        # softmax over T (the input length)
        attn_weights = F.softmax(attn_energies, dim=1).unsqueeze(1)
        return attn_weights

# %% [markdown]
# #### Decoder with Luong Attention
#
# We now define the decoder. Unlike the encoder (which processes the entire input
# sequence in one forward pass), the decoder is executed **one time step at a time**:
# at each step it receives a single token and produces a probability distribution
# over the vocabulary for the next token.
#
# Concretely, at decoding step $t$:
#
# - The input to the decoder is a tensor `input_step` of shape **(1, batch_size)**,
#   containing one token per sequence.
# - After embedding, this becomes **(1, batch_size, hidden_size)**.
# - The decoder updates its hidden state using a unidirectional GRU.
#
# A standard seq2seq decoder compresses the entire input into a fixed vector, which can lead to information loss—especially for longer sequences. To address this, we incorporate an **attention mechanism**.
#
#
# We use **Luong et al. (2015)** global attention:
# [Luong et al., 2015](https://arxiv.org/abs/1508.04025).
# At each decoding step, the decoder computes attention weights over all encoder time steps, then uses these weights to form a context vector (a weighted sum of encoder outputs). This context vector summarizes the parts of the input sentence that are most relevant for predicting the next word.

# %% [markdown]
# At each decoding step, the decoder should:
#
# 1. Embed the current input token.
# 2. Run one GRU step to update the decoder hidden state.
# 3. Compute attention weights using the current decoder state and encoder outputs.
# 4. Use the attention weights to compute a context vector.
# 5. Combine the decoder state and context vector.
# 6. Predict a probability distribution over the vocabulary.
#
# You are asked to implement both the **initialization** and **forward pass** of the Luong attention decoder according to this description.
#
# ---
#
# **Inputs**
#
# - `input_step`: one time step (one token) for each sequence in the batch
#   Shape: **(1, batch_size)**
#
# - `last_hidden`: previous decoder hidden state
#   Shape: **(n_layers, batch_size, hidden_size)**
#
# - `encoder_outputs`: encoder outputs for all time steps
#   Shape: **(max_length, batch_size, hidden_size)**
#
# **Outputs**
#
# - `output`: probability distribution over the vocabulary for the next token
#   Shape: **(batch_size, voc.num_words)**
#
# - `hidden`: updated decoder hidden state
#   Shape: **(n_layers, batch_size, hidden_size)**

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        # TODO: Implement
        super().__init__()
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)

        # Unidirectional GRU (decoder is typically not bidirectional)
        self.gru = nn.GRU(
            input_size=hidden_size,
            hidden_size=hidden_size,
            num_layers=n_layers,
            dropout=(0 if n_layers == 1 else dropout),
            bidirectional=False
        )

        # Luong attention
        self.attn = Attn(attn_model, hidden_size)

        # After attention: combine (context, rnn_output) -> hidden_size
        self.concat = nn.Linear(hidden_size * 2, hidden_size)

        # Project to vocab size
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # TODO: Implement

        # 1 Embed current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)

        # 2 Run through GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)


        # 3 Compute attention weights using current rnn_output
        attn_weights = self.attn(rnn_output, encoder_outputs)

        # 4 Compute context vector as weighted sum of encoder outputs
        encoder_outputs_t = encoder_outputs.transpose(0, 1)
        context = torch.bmm(attn_weights, encoder_outputs_t)

        # 5 Concatenate context with rnn output
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), dim=1)

        concat_output = torch.tanh(self.concat(concat_input))

        # 6 Predict next token
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)   # probabilities over vocab

        return output, hidden

# %% [markdown]
# ### Define Training Procedure

# %% [markdown]
# We now define the components required to train our seq2seq chatbot.
# Training is performed over mini-batches of padded sequences, which
# requires special care when computing the loss and updating model
# parameters.

# %% [markdown]
# #### Masked Loss
#
# Because batches contain padded sequences, not all positions in the target
# tensor correspond to valid words. We therefore compute the loss only over
# non-padding positions.
#
# The function below computes a **masked negative log-likelihood loss**,
# given the decoder’s output distribution, the target tokens, and a binary
# mask that indicates which positions are valid (i.e., not `PAD_token`).

# %%
def maskNLLLoss(inp, target, mask):
    """
    inp:    (batch_size, vocab_size) softmax probabilities
    target: (batch_size,) target token indices
    mask:   (batch_size,) boolean mask (True for valid tokens, False for PAD)
    """
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# #### Single Training Iteration
#
# We now describe a **single training iteration**, corresponding to one
# mini-batch update.
#
# During each iteration, we apply two commonly used techniques to improve
# training stability and convergence:
#
# - **Teacher forcing**: with some probability, the decoder receives the
#   ground-truth token as its next input instead of its own prediction.
#   This can significantly speed up training, but excessive teacher
#   forcing may lead to poor performance at inference time.
#
# - **Gradient clipping**: gradients are clipped to a maximum norm to
#   prevent the exploding gradient problem, which is particularly common
#   in recurrent neural networks.
#
# The sequence of operations for a single iteration is as follows:

# %% [markdown]
# #### Single Training Iteration (Implement)
#
# In this part you will implement a **single mini-batch update** for the
# seq2seq chatbot.
#
# You must handle two key ideas we covered in class:
#
# - **Teacher forcing**: with some probability, `teacher_forcing_ratio`, feed the ground-truth token as the next decoder input; otherwise, feed the model’s own prediction.
# - **Gradient clipping**: clip gradient norms to avoid exploding gradients in RNN training.
#
# Your implementation should follow this high-level sequence:

# %% [markdown]
# **Sequence of Operations**
#
# 1. Forward pass the input batch through the encoder.
# 2. Initialize the decoder input with `SOS_token` and the decoder hidden
#    state with the encoder’s final hidden state.
# 3. Decode one time step at a time:
#    - apply teacher forcing with probability `teacher_forcing_ratio`
#    - otherwise, feed the decoder’s own prediction as the next input
# 4. Compute and accumulate masked loss.
# 5. Backpropagate gradients.
# 6. Clip gradients.

# %% [markdown]
# Complete the function `train(...)` so that it performs one full mini-batch training update according to the sequence of operations described abov

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len,
          encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer,
          batch_size, clip, max_length=MAX_LENGTH):
    """
    Performs a single mini-batch update step.

    Inputs:
        input_variable:  (max_input_len, batch_size)
        lengths:         (batch_size,)  (must be on CPU for packing)
        target_variable: (max_target_len, batch_size)
        mask:            (max_target_len, batch_size) boolean
        max_target_len:  int

    Returns:
        avg_loss: average masked loss per non-PAD token (float)
    """

    # Move tensors to the correct device
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    lengths = lengths.to("cpu")  # required by pack_padded_sequence

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]]).to(device)


    decoder_hidden = encoder_hidden[:decoder.n_layers]

    use_teacher_forcing = (random.random() < teacher_forcing_ratio)

    # We will accumulate loss over time steps
    loss = 0
    print_losses = []
    n_totals = 0

    for t in range(max_target_len):
        decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden, encoder_outputs)
        # decoder_output: (B, vocab) probabilities (softmax), as required by maskNLLLoss

        # Teacher forcing or not
        if use_teacher_forcing:
            decoder_input = target_variable[t].view(1, -1)
        else:
            _, topi = decoder_output.topk(1)
            decoder_input = topi.transpose(0, 1).detach()

        # Loss for this timestep (mask ignores PAD targets)
        mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
        loss += mask_loss

        print_losses.append(mask_loss.item() * nTotal)
        n_totals += nTotal

    # Backprop
    loss.backward()

    # Clip gradients (prevents exploding gradients in RNNs) :contentReference[oaicite:2]{index=2}
    torch.nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    torch.nn.utils.clip_grad_norm_(decoder.parameters(), clip)


    # Update parameters
    encoder_optimizer.step()
    decoder_optimizer.step()
    # Return average loss per non-pad token
    return sum(print_losses) / n_totals

# %% [markdown]
# #### Training Loop
#
# We now wrap the single training iteration into a full training loop.
# At each iteration, a random mini-batch is sampled and one parameter
# update is performed.
#
# We periodically print training statistics and save model checkpoints,
# which include the encoder and decoder parameters, optimizer states, and
# vocabulary information.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration,
               batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    training_batches = [
        batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
        for _ in range(n_iteration)
    ]

    print('Initializing ...')
    start_iteration = 1
    print_loss = 0

    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        input_variable, lengths, target_variable, mask, max_target_len = training_batches[iteration - 1]

        loss = train(input_variable, lengths, target_variable, mask, max_target_len,
                     encoder, decoder, embedding,
                     encoder_optimizer, decoder_optimizer,
                     batch_size, clip)

        print_loss += loss

        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print(f"Iteration: {iteration}; Percent complete: {iteration / n_iteration * 100:.1f}%; Average loss: {print_loss_avg:.4f}")
            print_loss = 0

        if iteration % save_every == 0:
            directory = os.path.join(
                save_dir, model_name, corpus_name,
                f'{encoder_n_layers}-{decoder_n_layers}_{hidden_size}'
            )
            os.makedirs(directory, exist_ok=True)

            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, f'{iteration}_checkpoint.tar'))

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# After training the chatbot model, we would like to interact with it and
# generate responses to user-provided input sentences. To do so, we must
# define how the decoder generates an output sequence from the encoded
# input.
#
# During training, the decoder may receive ground-truth tokens as input
# (teacher forcing). During evaluation, however, the model must rely
# entirely on its own predictions. This requires defining an explicit
# **decoding strategy**.

# %% [markdown]
# #### Greedy Decoding
#
# We use **greedy decoding** to generate responses at evaluation time.
# At each decoding step, greedy decoding selects the word with the highest predicted probability from the decoder’s output distribution.
#
# Formally, given the decoder output distribution at time step $t$,
# greedy decoding chooses:
#
# $$
# \hat{w}_t = \arg\max_w \; p(w \mid w_{<t}, x)
# $$
#
# Greedy decoding is optimal at the level of individual time steps, though it does not guarantee a globally optimal sequence. Despite this
# limitation, it is simple, efficient, and serves as a strong baseline for sequence generation.

# %% [markdown]
# To implement greedy decoding, we define a `GreedySearchDecoder` module.
# This module wraps the encoder and decoder and performs decoding one time step at a time.
#
# Given an input sentence, decoding proceeds as follows:
#
# **Computation Graph**
#
# 1. Forward the input sequence through the encoder.
# 2. Initialize the decoder hidden state using the encoder’s final hidden state.
# 3. Initialize the decoder input with the `SOS_token`.
# 4. Iteratively decode one token at a time:
#    - Forward pass through the decoder.
#    - Select the most probable token.
#    - Feed the selected token as input to the next step.
# 5. Collect and return the generated tokens and their scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# #### Evaluating Text Input
#
# With the decoding procedure defined, we can now evaluate individual input sentences.
#
# The `evaluate` function handles the low-level mechanics of evaluation:
# it converts an input sentence into a tensor of word indices, prepares the appropriate length tensor, and runs greedy decoding to obtain the outputn sequence.
#
# The `evaluateInput` function provides a simple interactive interface for the chatbot. It repeatedly prompts the user for input, normalizes the sentence using the same preprocessing pipeline as the training data, and prints the decoded response. The interaction continues until the user enters `"q"` or `"quit"`.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    """
    Evaluate a single input sentence using greedy decoding.
    Out-of-vocabulary words are mapped to UNK_token.
    """
    # words -> indexes (UNK-safe)
    indexes = [
        voc.word2index.get(word, UNK_token)
        for word in sentence.split(' ')
    ] + [EOS_token]

    indexes_batch = [indexes]

    # Create lengths tensor
    lengths = torch.tensor([len(indexes)])

    # Prepare input batch (max_length, batch_size=1)
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")

    # Decode sentence
    tokens, scores = searcher(input_batch, lengths, max_length)

    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    """
    Interactive chatbot interface.
    Type 'q' or 'quit' to exit.
    """
    while True:
        # Get input sentence
        input_sentence = input('> ')
        if input_sentence in ('q', 'quit'):
            break

        # Normalize input
        input_sentence = normalizeString(input_sentence)

        # Evaluate sentence
        output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)

        # Remove EOS and PAD tokens from output
        output_words = [w for w in output_words if w not in ('EOS', 'PAD')]

        print('Bot:', ' '.join(output_words))

# %% [markdown]
# ### Run Model

# %% [markdown]
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from scratch or set a checkpoint to load from, and build and initialize the models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# #### Run Training
#
# Run the following block in order to train the model.
#
# First we set training parameters, then we initialize our optimizers, and finally we call the ``trainIters`` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9709
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8466
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6500
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.3876
# Iteration: 5; Percent complete: 0.1%; Average loss: 7.9858
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.4352
# Iteration: 7; Percent complete: 0.2%; Average loss: 7.0119
# Iteration: 8; Percent complete: 0.2%; Average loss: 7.0246
# Iteration: 9; Percent complete: 0.2%; Average loss: 7.1934
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.5477
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.2739
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.8432
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.7132
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.5243
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.7295
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.2304
# Iteration: 17; Percent complete: 0.4%; Average loss: 5.3019
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.4087
# Iteration: 19; Percent complete: 0.5%; Average loss: 4.9325
# Iteration: 20; Percent complete: 0.5%; Average loss: 5.1089
# Iteration: 21; Percent complete: 0.5%; Average loss: 5.3180
# Iteration: 22; Percent complete: 0.5%; Average loss: 5.1567
# Iteration: 23; Percent complete: 0.6%; Average loss: 5.1136
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.7864
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.8308
# Iteration: 26; Percent complete: 0.7%; Average loss: 5.0158
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.9020
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.5135
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.7723
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.5794
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.5184
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.8196
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.4427
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.7123
# Iteration: 35; Percent complete: 0.9%; Average loss: 5.0313
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.7949
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.6331
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.6007
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.7252
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.8222
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.6864
# Iteration: 42; Percent complete: 1.1%; Average loss: 4.6575
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.6653
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.8160
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.7442
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.7682
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.6611
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.3727
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.7055
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.8182
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.7221
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.6856
# Iteration: 53; Percent complete: 1.3%; Average loss: 4.8594
# Iteration: 54; Percent complete: 1.4%; Average loss: 4.5361
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.5395
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.6044
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.5999
# Iteration: 58; Percent complete: 1.5%; Average loss: 4.5429
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.3967
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.4336
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.7038
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.6642
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.6034
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.5346
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.4481
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.6474
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.6753
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.3982
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.4086
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.6055
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.4286
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.4129
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.4373
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.3926
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.6337
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.4888
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.3723
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.5112
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.6722
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.4367
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.3777
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.5230
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.6012
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.5398
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.2685
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.4683
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.5352
# Iteration: 88; Percent complete: 2.2%; Average loss: 4.5929
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.5130
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.4839
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.2979
# Iteration: 92; Percent complete: 2.3%; Average loss: 4.5769
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.3126
# Iteration: 94; Percent complete: 2.4%; Average loss: 4.3644
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.3314
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.2877
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.5268
# Iteration: 98; Percent complete: 2.5%; Average loss: 4.4302
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.5494
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.3986
# Iteration: 101; Percent complete: 2.5%; Average loss: 4.5787
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.3799
# Iteration: 103; Percent complete: 2.6%; Average loss: 4.3454
# Iteration: 104; Percent complete: 2.6%; Average loss: 4.4650
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.2913
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.6192
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.1951
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.1569
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.5254
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.3824
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.1825
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.5606
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.0942
# Iteration: 114; Percent complete: 2.9%; Average loss: 4.7240
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.3540
# Iteration: 116; Percent complete: 2.9%; Average loss: 4.2848
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.1264
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.4002
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.3721
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.3216
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.2400
# Iteration: 122; Percent complete: 3.0%; Average loss: 4.1183
# Iteration: 123; Percent complete: 3.1%; Average loss: 4.2968
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.3891
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.3797
# Iteration: 126; Percent complete: 3.1%; Average loss: 4.5231
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.4311
# Iteration: 128; Percent complete: 3.2%; Average loss: 4.3562
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.3036
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.1914
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.2228
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.3599
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.0727
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.1714
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.0875
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.0578
# Iteration: 137; Percent complete: 3.4%; Average loss: 3.9928
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.3909
# Iteration: 139; Percent complete: 3.5%; Average loss: 4.2317
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.2876
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.0288
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.3075
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.2393
# Iteration: 144; Percent complete: 3.6%; Average loss: 4.4590
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.1468
# Iteration: 146; Percent complete: 3.6%; Average loss: 4.2323
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.4740
# Iteration: 148; Percent complete: 3.7%; Average loss: 3.9390
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.2037
# Iteration: 150; Percent complete: 3.8%; Average loss: 4.0764
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.0764
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.1971
# Iteration: 153; Percent complete: 3.8%; Average loss: 3.9484
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.3352
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.0295
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.2136
# Iteration: 157; Percent complete: 3.9%; Average loss: 4.0463
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.2036
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.0655
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.1409
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.3847
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.3190
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.2399
# Iteration: 164; Percent complete: 4.1%; Average loss: 3.9954
# Iteration: 165; Percent complete: 4.1%; Average loss: 4.2424
# Iteration: 166; Percent complete: 4.2%; Average loss: 3.9514
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.2193
# Iteration: 168; Percent complete: 4.2%; Average loss: 4.2933
# Iteration: 169; Percent complete: 4.2%; Average loss: 4.3888
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.0995
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.3266
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.0859
# Iteration: 173; Percent complete: 4.3%; Average loss: 4.4000
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.1458
# Iteration: 175; Percent complete: 4.4%; Average loss: 4.1908
# Iteration: 176; Percent complete: 4.4%; Average loss: 3.9429
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.1500
# Iteration: 178; Percent complete: 4.5%; Average loss: 4.0422
# Iteration: 179; Percent complete: 4.5%; Average loss: 4.1207
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.2848
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.4325
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.3391
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.0532
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.0394
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.2308
# Iteration: 186; Percent complete: 4.7%; Average loss: 3.9989
# Iteration: 187; Percent complete: 4.7%; Average loss: 3.9523
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.2751
# Iteration: 189; Percent complete: 4.7%; Average loss: 4.2681
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.0181
# Iteration: 191; Percent complete: 4.8%; Average loss: 4.0035
# Iteration: 192; Percent complete: 4.8%; Average loss: 4.2627
# Iteration: 193; Percent complete: 4.8%; Average loss: 4.2233
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.0551
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.2409
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.0695
# Iteration: 197; Percent complete: 4.9%; Average loss: 3.8143
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.1795
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.0302
# Iteration: 200; Percent complete: 5.0%; Average loss: 3.9472
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.3444
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.3988
# Iteration: 203; Percent complete: 5.1%; Average loss: 3.9422
# Iteration: 204; Percent complete: 5.1%; Average loss: 4.1915
# Iteration: 205; Percent complete: 5.1%; Average loss: 4.0544
# Iteration: 206; Percent complete: 5.1%; Average loss: 3.9787
# Iteration: 207; Percent complete: 5.2%; Average loss: 3.9642
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.1661
# Iteration: 209; Percent complete: 5.2%; Average loss: 3.8897
# Iteration: 210; Percent complete: 5.2%; Average loss: 4.1375
# Iteration: 211; Percent complete: 5.3%; Average loss: 3.9983
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.2224
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.2209
# Iteration: 214; Percent complete: 5.3%; Average loss: 3.6947
# Iteration: 215; Percent complete: 5.4%; Average loss: 3.8824
# Iteration: 216; Percent complete: 5.4%; Average loss: 4.0572
# Iteration: 217; Percent complete: 5.4%; Average loss: 4.0788
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.0942
# Iteration: 219; Percent complete: 5.5%; Average loss: 3.9767
# Iteration: 220; Percent complete: 5.5%; Average loss: 4.0240
# Iteration: 221; Percent complete: 5.5%; Average loss: 3.9654
# Iteration: 222; Percent complete: 5.5%; Average loss: 3.8626
# Iteration: 223; Percent complete: 5.6%; Average loss: 3.8284
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.0814
# Iteration: 225; Percent complete: 5.6%; Average loss: 4.1376
# Iteration: 226; Percent complete: 5.7%; Average loss: 4.2109
# Iteration: 227; Percent complete: 5.7%; Average loss: 4.2658
# Iteration: 228; Percent complete: 5.7%; Average loss: 4.1397
# Iteration: 229; Percent complete: 5.7%; Average loss: 4.2603
# Iteration: 230; Percent complete: 5.8%; Average loss: 3.9490
# Iteration: 231; Percent complete: 5.8%; Average loss: 4.0526
# Iteration: 232; Percent complete: 5.8%; Average loss: 4.0118
# Iteration: 233; Percent complete: 5.8%; Average loss: 4.0050
# Iteration: 234; Percent complete: 5.9%; Average loss: 4.1129
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.0422
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.0161
# Iteration: 237; Percent complete: 5.9%; Average loss: 3.9856
# Iteration: 238; Percent complete: 5.9%; Average loss: 3.8184
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.0500
# Iteration: 240; Percent complete: 6.0%; Average loss: 3.7497
# Iteration: 241; Percent complete: 6.0%; Average loss: 3.9075
# Iteration: 242; Percent complete: 6.0%; Average loss: 3.8800
# Iteration: 243; Percent complete: 6.1%; Average loss: 3.9103
# Iteration: 244; Percent complete: 6.1%; Average loss: 4.1717
# Iteration: 245; Percent complete: 6.1%; Average loss: 3.6683
# Iteration: 246; Percent complete: 6.2%; Average loss: 3.8521
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.0182
# Iteration: 248; Percent complete: 6.2%; Average loss: 3.8950
# Iteration: 249; Percent complete: 6.2%; Average loss: 3.8507
# Iteration: 250; Percent complete: 6.2%; Average loss: 4.2594
# Iteration: 251; Percent complete: 6.3%; Average loss: 4.1370
# Iteration: 252; Percent complete: 6.3%; Average loss: 3.9967
# Iteration: 253; Percent complete: 6.3%; Average loss: 4.0797
# Iteration: 254; Percent complete: 6.3%; Average loss: 4.0209
# Iteration: 255; Percent complete: 6.4%; Average loss: 4.0312
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.9204
# Iteration: 257; Percent complete: 6.4%; Average loss: 4.2348
# Iteration: 258; Percent complete: 6.5%; Average loss: 4.2531
# Iteration: 259; Percent complete: 6.5%; Average loss: 4.0583
# Iteration: 260; Percent complete: 6.5%; Average loss: 4.1213
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.7639
# Iteration: 262; Percent complete: 6.6%; Average loss: 3.9461
# Iteration: 263; Percent complete: 6.6%; Average loss: 4.1773
# Iteration: 264; Percent complete: 6.6%; Average loss: 3.6833
# Iteration: 265; Percent complete: 6.6%; Average loss: 3.6095
# Iteration: 266; Percent complete: 6.7%; Average loss: 4.0243
# Iteration: 267; Percent complete: 6.7%; Average loss: 3.9299
# Iteration: 268; Percent complete: 6.7%; Average loss: 3.7605
# Iteration: 269; Percent complete: 6.7%; Average loss: 4.0153
# Iteration: 270; Percent complete: 6.8%; Average loss: 3.7316
# Iteration: 271; Percent complete: 6.8%; Average loss: 4.0621
# Iteration: 272; Percent complete: 6.8%; Average loss: 4.1658
# Iteration: 273; Percent complete: 6.8%; Average loss: 4.1684
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.8439
# Iteration: 275; Percent complete: 6.9%; Average loss: 4.1638
# Iteration: 276; Percent complete: 6.9%; Average loss: 4.1167
# Iteration: 277; Percent complete: 6.9%; Average loss: 3.7816
# Iteration: 278; Percent complete: 7.0%; Average loss: 4.0137
# Iteration: 279; Percent complete: 7.0%; Average loss: 4.0342
# Iteration: 280; Percent complete: 7.0%; Average loss: 3.8939
# Iteration: 281; Percent complete: 7.0%; Average loss: 4.0652
# Iteration: 282; Percent complete: 7.0%; Average loss: 3.7034
# Iteration: 283; Percent complete: 7.1%; Average loss: 3.9266
# Iteration: 284; Percent complete: 7.1%; Average loss: 4.0377
# Iteration: 285; Percent complete: 7.1%; Average loss: 4.0442
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.8364
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.7764
# Iteration: 288; Percent complete: 7.2%; Average loss: 4.0964
# Iteration: 289; Percent complete: 7.2%; Average loss: 3.8743
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.0519
# Iteration: 291; Percent complete: 7.3%; Average loss: 3.9804
# Iteration: 292; Percent complete: 7.3%; Average loss: 3.8145
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.3481
# Iteration: 294; Percent complete: 7.3%; Average loss: 3.8725
# Iteration: 295; Percent complete: 7.4%; Average loss: 4.0443
# Iteration: 296; Percent complete: 7.4%; Average loss: 3.9045
# Iteration: 297; Percent complete: 7.4%; Average loss: 3.9605
# Iteration: 298; Percent complete: 7.4%; Average loss: 4.1079
# Iteration: 299; Percent complete: 7.5%; Average loss: 3.8689
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.8748
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.8519
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.6740
# Iteration: 303; Percent complete: 7.6%; Average loss: 3.8957
# Iteration: 304; Percent complete: 7.6%; Average loss: 4.0628
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.9625
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.7437
# Iteration: 307; Percent complete: 7.7%; Average loss: 4.0180
# Iteration: 308; Percent complete: 7.7%; Average loss: 4.1582
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.9171
# Iteration: 310; Percent complete: 7.8%; Average loss: 3.9605
# Iteration: 311; Percent complete: 7.8%; Average loss: 3.9255
# Iteration: 312; Percent complete: 7.8%; Average loss: 4.2061
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.6583
# Iteration: 314; Percent complete: 7.8%; Average loss: 3.8853
# Iteration: 315; Percent complete: 7.9%; Average loss: 3.7559
# Iteration: 316; Percent complete: 7.9%; Average loss: 3.8246
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.8621
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.8359
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.9200
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.8510
# Iteration: 321; Percent complete: 8.0%; Average loss: 3.7822
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.8778
# Iteration: 323; Percent complete: 8.1%; Average loss: 3.9172
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.5826
# Iteration: 325; Percent complete: 8.1%; Average loss: 3.6927
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.6193
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.8042
# Iteration: 328; Percent complete: 8.2%; Average loss: 3.7286
# Iteration: 329; Percent complete: 8.2%; Average loss: 4.0932
# Iteration: 330; Percent complete: 8.2%; Average loss: 3.8717
# Iteration: 331; Percent complete: 8.3%; Average loss: 3.8706
# Iteration: 332; Percent complete: 8.3%; Average loss: 4.2647
# Iteration: 333; Percent complete: 8.3%; Average loss: 3.8381
# Iteration: 334; Percent complete: 8.3%; Average loss: 4.0110
# Iteration: 335; Percent complete: 8.4%; Average loss: 3.7775
# Iteration: 336; Percent complete: 8.4%; Average loss: 4.0871
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.8586
# Iteration: 338; Percent complete: 8.5%; Average loss: 3.8638
# Iteration: 339; Percent complete: 8.5%; Average loss: 4.0873
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.8332
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.9102
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.9376
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.8666
# Iteration: 344; Percent complete: 8.6%; Average loss: 3.8123
# Iteration: 345; Percent complete: 8.6%; Average loss: 4.1494
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.8243
# Iteration: 347; Percent complete: 8.7%; Average loss: 4.0042
# Iteration: 348; Percent complete: 8.7%; Average loss: 4.0386
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.6832
# Iteration: 350; Percent complete: 8.8%; Average loss: 3.6643
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.7780
# Iteration: 352; Percent complete: 8.8%; Average loss: 3.8571
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.8552
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.7684
# Iteration: 355; Percent complete: 8.9%; Average loss: 4.1515
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.6844
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.8371
# Iteration: 358; Percent complete: 8.9%; Average loss: 3.8631
# Iteration: 359; Percent complete: 9.0%; Average loss: 3.7741
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.9717
# Iteration: 361; Percent complete: 9.0%; Average loss: 3.5749
# Iteration: 362; Percent complete: 9.0%; Average loss: 4.0974
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.7911
# Iteration: 364; Percent complete: 9.1%; Average loss: 3.8686
# Iteration: 365; Percent complete: 9.1%; Average loss: 3.7164
# Iteration: 366; Percent complete: 9.2%; Average loss: 3.6850
# Iteration: 367; Percent complete: 9.2%; Average loss: 3.6715
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.9029
# Iteration: 369; Percent complete: 9.2%; Average loss: 4.2691
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.8069
# Iteration: 371; Percent complete: 9.3%; Average loss: 3.5708
# Iteration: 372; Percent complete: 9.3%; Average loss: 3.8889
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.8336
# Iteration: 374; Percent complete: 9.3%; Average loss: 4.0952
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.8391
# Iteration: 376; Percent complete: 9.4%; Average loss: 4.1514
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.7894
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.9898
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.7180
# Iteration: 380; Percent complete: 9.5%; Average loss: 3.7989
# Iteration: 381; Percent complete: 9.5%; Average loss: 4.0068
# Iteration: 382; Percent complete: 9.6%; Average loss: 4.1006
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.7152
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.8655
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.5471
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.7116
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.7518
# Iteration: 388; Percent complete: 9.7%; Average loss: 4.1707
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.7280
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.7637
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.6357
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.8684
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.9175
# Iteration: 394; Percent complete: 9.8%; Average loss: 3.8966
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.8547
# Iteration: 396; Percent complete: 9.9%; Average loss: 3.6413
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.8624
# Iteration: 398; Percent complete: 10.0%; Average loss: 3.7973
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.7760
# Iteration: 400; Percent complete: 10.0%; Average loss: 3.8298
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.7901
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.9018
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.3705
# Iteration: 404; Percent complete: 10.1%; Average loss: 3.8168
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.9284
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.9560
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.8811
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.8199
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.6771
# Iteration: 410; Percent complete: 10.2%; Average loss: 4.0713
# Iteration: 411; Percent complete: 10.3%; Average loss: 3.6440
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.6132
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.7270
# Iteration: 414; Percent complete: 10.3%; Average loss: 4.0769
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.7068
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.9267
# Iteration: 417; Percent complete: 10.4%; Average loss: 3.7466
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.9587
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.7818
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.9705
# Iteration: 421; Percent complete: 10.5%; Average loss: 3.5901
# Iteration: 422; Percent complete: 10.5%; Average loss: 3.8842
# Iteration: 423; Percent complete: 10.6%; Average loss: 3.7573
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.8183
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.6032
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.9620
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.7542
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.9074
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.7957
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.8302
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.6938
# Iteration: 432; Percent complete: 10.8%; Average loss: 3.6418
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.7399
# Iteration: 434; Percent complete: 10.8%; Average loss: 4.1048
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.6715
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.9228
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.9015
# Iteration: 438; Percent complete: 10.9%; Average loss: 3.7776
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.7154
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.9247
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.8725
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.8134
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.9654
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.8148
# Iteration: 445; Percent complete: 11.1%; Average loss: 3.6279
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.4667
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.8902
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.8047
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.6092
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.5738
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.8882
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.9415
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.6521
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.7996
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.7446
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.5500
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.9060
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.6572
# Iteration: 459; Percent complete: 11.5%; Average loss: 3.9848
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.9183
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.7137
# Iteration: 462; Percent complete: 11.6%; Average loss: 3.6499
# Iteration: 463; Percent complete: 11.6%; Average loss: 4.0103
# Iteration: 464; Percent complete: 11.6%; Average loss: 3.7478
# Iteration: 465; Percent complete: 11.6%; Average loss: 3.7962
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.8002
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.6385
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.5895
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.9534
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.8057
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.7768
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.3577
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.9317
# Iteration: 474; Percent complete: 11.8%; Average loss: 4.0593
# Iteration: 475; Percent complete: 11.9%; Average loss: 3.7589
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.5002
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.8472
# Iteration: 478; Percent complete: 11.9%; Average loss: 3.6023
# Iteration: 479; Percent complete: 12.0%; Average loss: 3.8373
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.7677
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.9797
# Iteration: 482; Percent complete: 12.0%; Average loss: 3.7168
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.9782
# Iteration: 484; Percent complete: 12.1%; Average loss: 3.7653
# Iteration: 485; Percent complete: 12.1%; Average loss: 3.7949
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.9062
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.7693
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.8873
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.5336
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.7869
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.7989
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.8494
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.6872
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.8964
# Iteration: 495; Percent complete: 12.4%; Average loss: 3.6017
# Iteration: 496; Percent complete: 12.4%; Average loss: 4.0402
# Iteration: 497; Percent complete: 12.4%; Average loss: 3.5884
# Iteration: 498; Percent complete: 12.4%; Average loss: 3.6889
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.5283
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.5682
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.8305
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.7935
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.7051
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.5345
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.6907
# Iteration: 506; Percent complete: 12.7%; Average loss: 3.7420
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.6558
# Iteration: 508; Percent complete: 12.7%; Average loss: 3.8562
# Iteration: 509; Percent complete: 12.7%; Average loss: 4.2135
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.8438
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.5950
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.7286
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.7905
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.9370
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.3322
# Iteration: 516; Percent complete: 12.9%; Average loss: 3.8064
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.6466
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.5105
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.4789
# Iteration: 520; Percent complete: 13.0%; Average loss: 3.7976
# Iteration: 521; Percent complete: 13.0%; Average loss: 3.7930
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.6839
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.7160
# Iteration: 524; Percent complete: 13.1%; Average loss: 3.8086
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.6569
# Iteration: 526; Percent complete: 13.2%; Average loss: 3.6041
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.7545
# Iteration: 528; Percent complete: 13.2%; Average loss: 3.6556
# Iteration: 529; Percent complete: 13.2%; Average loss: 3.6720
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.5084
# Iteration: 531; Percent complete: 13.3%; Average loss: 3.5773
# Iteration: 532; Percent complete: 13.3%; Average loss: 3.8306
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.7666
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.8140
# Iteration: 535; Percent complete: 13.4%; Average loss: 3.9723
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.6277
# Iteration: 537; Percent complete: 13.4%; Average loss: 3.6723
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.8739
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.4219
# Iteration: 540; Percent complete: 13.5%; Average loss: 3.7676
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.7120
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.9046
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.7297
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.7424
# Iteration: 545; Percent complete: 13.6%; Average loss: 3.8364
# Iteration: 546; Percent complete: 13.7%; Average loss: 3.5691
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.8458
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.6591
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.7135
# Iteration: 550; Percent complete: 13.8%; Average loss: 3.6741
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.7176
# Iteration: 552; Percent complete: 13.8%; Average loss: 3.7368
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.7007
# Iteration: 554; Percent complete: 13.9%; Average loss: 3.5400
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.5385
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.5321
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.9232
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.4688
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.7675
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.6325
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.5496
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.5711
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.8062
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.7385
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.6834
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.6699
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.7446
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.8099
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.7572
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.8371
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.5730
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.6881
# Iteration: 573; Percent complete: 14.3%; Average loss: 3.7947
# Iteration: 574; Percent complete: 14.3%; Average loss: 3.3490
# Iteration: 575; Percent complete: 14.4%; Average loss: 3.7650
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.5605
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.6738
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.5284
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.3614
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.6862
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.5248
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.1713
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.7106
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.5534
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.8064
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.3631
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.7266
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.7956
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.8591
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.6067
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.6684
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.6300
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.5508
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.6090
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.9265
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.5023
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.5972
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.5882
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.6179
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.5969
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.7045
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.7100
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.7560
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.5577
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.4480
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.8154
# Iteration: 607; Percent complete: 15.2%; Average loss: 3.8344
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.5821
# Iteration: 609; Percent complete: 15.2%; Average loss: 3.5778
# Iteration: 610; Percent complete: 15.2%; Average loss: 3.8178
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.6977
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.8795
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.5326
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.6793
# Iteration: 615; Percent complete: 15.4%; Average loss: 3.6853
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.6157
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.7756
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.7365
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.9665
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.5823
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.2927
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.5783
# Iteration: 623; Percent complete: 15.6%; Average loss: 3.4394
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.5317
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.6076
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.5974
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.4464
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.7377
# Iteration: 629; Percent complete: 15.7%; Average loss: 3.8318
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.5969
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.5991
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.5776
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.3702
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.6390
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.5809
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.4297
# Iteration: 637; Percent complete: 15.9%; Average loss: 3.5782
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.5144
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.7293
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.8428
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.3847
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.6683
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.8310
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.5385
# Iteration: 645; Percent complete: 16.1%; Average loss: 3.5836
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.8674
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.5338
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.5224
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.6885
# Iteration: 650; Percent complete: 16.2%; Average loss: 3.6298
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.4750
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.6694
# Iteration: 653; Percent complete: 16.3%; Average loss: 3.6601
# Iteration: 654; Percent complete: 16.4%; Average loss: 3.6184
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.4741
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.9275
# Iteration: 657; Percent complete: 16.4%; Average loss: 3.6109
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.6971
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.7187
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.9080
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.5250
# Iteration: 662; Percent complete: 16.6%; Average loss: 3.7739
# Iteration: 663; Percent complete: 16.6%; Average loss: 3.3873
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.8313
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.7619
# Iteration: 666; Percent complete: 16.7%; Average loss: 3.5130
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.9421
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.3818
# Iteration: 669; Percent complete: 16.7%; Average loss: 3.7841
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.4702
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.6398
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.6316
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.5016
# Iteration: 674; Percent complete: 16.9%; Average loss: 3.5842
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.7148
# Iteration: 676; Percent complete: 16.9%; Average loss: 3.9447
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.5485
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.5625
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.5626
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.4656
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.6812
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.4038
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.5176
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.7730
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.6320
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.5009
# Iteration: 687; Percent complete: 17.2%; Average loss: 3.5704
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.4631
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.7163
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.5898
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.6524
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.6358
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.6279
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.7828
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.4877
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.2964
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.6016
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.6166
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.5014
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.7187
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.4835
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.6725
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.6138
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.6113
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.6603
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.6593
# Iteration: 707; Percent complete: 17.7%; Average loss: 3.7676
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.7436
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.5763
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.6468
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.5207
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.5971
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.6197
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.8851
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.4606
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.4273
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.5131
# Iteration: 718; Percent complete: 17.9%; Average loss: 3.6527
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.4031
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.4052
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.6453
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.6212
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.2667
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.6694
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.5606
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.7956
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.2251
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.7328
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.3670
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.4733
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.3026
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.8328
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.6773
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.4679
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.9298
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.6796
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.7493
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.8212
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.5180
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.8841
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.7120
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.5462
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.4432
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.5091
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.6443
# Iteration: 746; Percent complete: 18.6%; Average loss: 3.4643
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.9051
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.5394
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.6302
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.4653
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.8393
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.7594
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.4312
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.4439
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.4115
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.5489
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.6621
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.5506
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.4642
# Iteration: 760; Percent complete: 19.0%; Average loss: 3.4614
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.5282
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.4082
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.6244
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.5858
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.5271
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.4748
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.4875
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.5844
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.5787
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.3064
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.4641
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.4710
# Iteration: 773; Percent complete: 19.3%; Average loss: 3.5067
# Iteration: 774; Percent complete: 19.4%; Average loss: 3.5509
# Iteration: 775; Percent complete: 19.4%; Average loss: 3.5867
# Iteration: 776; Percent complete: 19.4%; Average loss: 3.4408
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.6365
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.7263
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.5931
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.6129
# Iteration: 781; Percent complete: 19.5%; Average loss: 3.6017
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 2.7883
# Iteration: 3749; Percent complete: 93.7%; Average loss: 2.5635
# Iteration: 3750; Percent complete: 93.8%; Average loss: 2.5032
# Iteration: 3751; Percent complete: 93.8%; Average loss: 2.8214
# Iteration: 3752; Percent complete: 93.8%; Average loss: 2.5970
# Iteration: 3753; Percent complete: 93.8%; Average loss: 2.5741
# Iteration: 3754; Percent complete: 93.8%; Average loss: 2.6049
# Iteration: 3755; Percent complete: 93.9%; Average loss: 2.7106
# Iteration: 3756; Percent complete: 93.9%; Average loss: 2.5505
# Iteration: 3757; Percent complete: 93.9%; Average loss: 2.7147
# Iteration: 3758; Percent complete: 94.0%; Average loss: 2.6412
# Iteration: 3759; Percent complete: 94.0%; Average loss: 2.5957
# Iteration: 3760; Percent complete: 94.0%; Average loss: 2.4588
# Iteration: 3761; Percent complete: 94.0%; Average loss: 2.7380
# Iteration: 3762; Percent complete: 94.0%; Average loss: 2.6495
# Iteration: 3763; Percent complete: 94.1%; Average loss: 2.8423
# Iteration: 3764; Percent complete: 94.1%; Average loss: 2.8097
# Iteration: 3765; Percent complete: 94.1%; Average loss: 2.5950
# Iteration: 3766; Percent complete: 94.2%; Average loss: 2.7207
# Iteration: 3767; Percent complete: 94.2%; Average loss: 2.6008
# Iteration: 3768; Percent complete: 94.2%; Average loss: 2.5504
# Iteration: 3769; Percent complete: 94.2%; Average loss: 2.6477
# Iteration: 3770; Percent complete: 94.2%; Average loss: 2.7614
# Iteration: 3771; Percent complete: 94.3%; Average loss: 2.5852
# Iteration: 3772; Percent complete: 94.3%; Average loss: 2.8624
# Iteration: 3773; Percent complete: 94.3%; Average loss: 2.6382
# Iteration: 3774; Percent complete: 94.3%; Average loss: 2.7271
# Iteration: 3775; Percent complete: 94.4%; Average loss: 2.8516
# Iteration: 3776; Percent complete: 94.4%; Average loss: 2.6786
# Iteration: 3777; Percent complete: 94.4%; Average loss: 2.3914
# Iteration: 3778; Percent complete: 94.5%; Average loss: 2.6557
# Iteration: 3779; Percent complete: 94.5%; Average loss: 2.7617
# Iteration: 3780; Percent complete: 94.5%; Average loss: 2.5719
# Iteration: 3781; Percent complete: 94.5%; Average loss: 2.7066
# Iteration: 3782; Percent complete: 94.5%; Average loss: 2.8757
# Iteration: 3783; Percent complete: 94.6%; Average loss: 2.7037
# Iteration: 3784; Percent complete: 94.6%; Average loss: 2.4402
# Iteration: 3785; Percent complete: 94.6%; Average loss: 2.7481
# Iteration: 3786; Percent complete: 94.7%; Average loss: 2.7578
# Iteration: 3787; Percent complete: 94.7%; Average loss: 2.7710
# Iteration: 3788; Percent complete: 94.7%; Average loss: 2.5368
# Iteration: 3789; Percent complete: 94.7%; Average loss: 2.7570
# Iteration: 3790; Percent complete: 94.8%; Average loss: 2.6811
# Iteration: 3791; Percent complete: 94.8%; Average loss: 2.6431
# Iteration: 3792; Percent complete: 94.8%; Average loss: 2.6920
# Iteration: 3793; Percent complete: 94.8%; Average loss: 2.5837
# Iteration: 3794; Percent complete: 94.8%; Average loss: 2.6792
# Iteration: 3795; Percent complete: 94.9%; Average loss: 2.7243
# Iteration: 3796; Percent complete: 94.9%; Average loss: 2.5433
# Iteration: 3797; Percent complete: 94.9%; Average loss: 2.7491
# Iteration: 3798; Percent complete: 95.0%; Average loss: 2.6384
# Iteration: 3799; Percent complete: 95.0%; Average loss: 2.7329
# Iteration: 3800; Percent complete: 95.0%; Average loss: 2.7742
# Iteration: 3801; Percent complete: 95.0%; Average loss: 2.7194
# Iteration: 3802; Percent complete: 95.0%; Average loss: 2.8112
# Iteration: 3803; Percent complete: 95.1%; Average loss: 2.4917
# Iteration: 3804; Percent complete: 95.1%; Average loss: 2.6244
# Iteration: 3805; Percent complete: 95.1%; Average loss: 2.4286
# Iteration: 3806; Percent complete: 95.2%; Average loss: 2.5634
# Iteration: 3807; Percent complete: 95.2%; Average loss: 2.5833
# Iteration: 3808; Percent complete: 95.2%; Average loss: 2.7074
# Iteration: 3809; Percent complete: 95.2%; Average loss: 2.5397
# Iteration: 3810; Percent complete: 95.2%; Average loss: 2.6832
# Iteration: 3811; Percent complete: 95.3%; Average loss: 2.5535
# Iteration: 3812; Percent complete: 95.3%; Average loss: 2.4436
# Iteration: 3813; Percent complete: 95.3%; Average loss: 2.7223
# Iteration: 3814; Percent complete: 95.3%; Average loss: 2.5973
# Iteration: 3815; Percent complete: 95.4%; Average loss: 2.7892
# Iteration: 3816; Percent complete: 95.4%; Average loss: 2.4818
# Iteration: 3817; Percent complete: 95.4%; Average loss: 2.4987
# Iteration: 3818; Percent complete: 95.5%; Average loss: 2.7572
# Iteration: 3819; Percent complete: 95.5%; Average loss: 2.8357
# Iteration: 3820; Percent complete: 95.5%; Average loss: 2.7292
# Iteration: 3821; Percent complete: 95.5%; Average loss: 2.5881
# Iteration: 3822; Percent complete: 95.5%; Average loss: 2.6510
# Iteration: 3823; Percent complete: 95.6%; Average loss: 2.9153
# Iteration: 3824; Percent complete: 95.6%; Average loss: 2.4883
# Iteration: 3825; Percent complete: 95.6%; Average loss: 2.4926
# Iteration: 3826; Percent complete: 95.7%; Average loss: 2.6487
# Iteration: 3827; Percent complete: 95.7%; Average loss: 2.5586
# Iteration: 3828; Percent complete: 95.7%; Average loss: 2.3974
# Iteration: 3829; Percent complete: 95.7%; Average loss: 2.5871
# Iteration: 3830; Percent complete: 95.8%; Average loss: 2.6613
# Iteration: 3831; Percent complete: 95.8%; Average loss: 2.4998
# Iteration: 3832; Percent complete: 95.8%; Average loss: 2.7032
# Iteration: 3833; Percent complete: 95.8%; Average loss: 2.6361
# Iteration: 3834; Percent complete: 95.9%; Average loss: 2.5744
# Iteration: 3835; Percent complete: 95.9%; Average loss: 2.4024
# Iteration: 3836; Percent complete: 95.9%; Average loss: 2.5197
# Iteration: 3837; Percent complete: 95.9%; Average loss: 2.7882
# Iteration: 3838; Percent complete: 96.0%; Average loss: 2.7231
# Iteration: 3839; Percent complete: 96.0%; Average loss: 2.6624
# Iteration: 3840; Percent complete: 96.0%; Average loss: 2.6368
# Iteration: 3841; Percent complete: 96.0%; Average loss: 2.6544
# Iteration: 3842; Percent complete: 96.0%; Average loss: 2.6167
# Iteration: 3843; Percent complete: 96.1%; Average loss: 2.9888
# Iteration: 3844; Percent complete: 96.1%; Average loss: 2.5542
# Iteration: 3845; Percent complete: 96.1%; Average loss: 2.6282
# Iteration: 3846; Percent complete: 96.2%; Average loss: 2.7538
# Iteration: 3847; Percent complete: 96.2%; Average loss: 2.7025
# Iteration: 3848; Percent complete: 96.2%; Average loss: 2.6056
# Iteration: 3849; Percent complete: 96.2%; Average loss: 2.7844
# Iteration: 3850; Percent complete: 96.2%; Average loss: 2.5920
# Iteration: 3851; Percent complete: 96.3%; Average loss: 2.5708
# Iteration: 3852; Percent complete: 96.3%; Average loss: 2.7427
# Iteration: 3853; Percent complete: 96.3%; Average loss: 2.8868
# Iteration: 3854; Percent complete: 96.4%; Average loss: 2.7963
# Iteration: 3855; Percent complete: 96.4%; Average loss: 2.5675
# Iteration: 3856; Percent complete: 96.4%; Average loss: 2.4131
# Iteration: 3857; Percent complete: 96.4%; Average loss: 2.6350
# Iteration: 3858; Percent complete: 96.5%; Average loss: 2.4275
# Iteration: 3859; Percent complete: 96.5%; Average loss: 2.7010
# Iteration: 3860; Percent complete: 96.5%; Average loss: 2.4967
# Iteration: 3861; Percent complete: 96.5%; Average loss: 2.4904
# Iteration: 3862; Percent complete: 96.5%; Average loss: 2.8475
# Iteration: 3863; Percent complete: 96.6%; Average loss: 2.7171
# Iteration: 3864; Percent complete: 96.6%; Average loss: 2.5618
# Iteration: 3865; Percent complete: 96.6%; Average loss: 2.7697
# Iteration: 3866; Percent complete: 96.7%; Average loss: 2.6822
# Iteration: 3867; Percent complete: 96.7%; Average loss: 2.7920
# Iteration: 3868; Percent complete: 96.7%; Average loss: 2.6125
# Iteration: 3869; Percent complete: 96.7%; Average loss: 2.6549
# Iteration: 3870; Percent complete: 96.8%; Average loss: 2.7301
# Iteration: 3871; Percent complete: 96.8%; Average loss: 2.6459
# Iteration: 3872; Percent complete: 96.8%; Average loss: 2.7203
# Iteration: 3873; Percent complete: 96.8%; Average loss: 2.6887
# Iteration: 3874; Percent complete: 96.9%; Average loss: 2.4640
# Iteration: 3875; Percent complete: 96.9%; Average loss: 2.4541
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.5086
# Iteration: 3877; Percent complete: 96.9%; Average loss: 2.6951
# Iteration: 3878; Percent complete: 97.0%; Average loss: 2.5527
# Iteration: 3879; Percent complete: 97.0%; Average loss: 2.5103
# Iteration: 3880; Percent complete: 97.0%; Average loss: 2.5633
# Iteration: 3881; Percent complete: 97.0%; Average loss: 2.4856
# Iteration: 3882; Percent complete: 97.0%; Average loss: 2.6121
# Iteration: 3883; Percent complete: 97.1%; Average loss: 2.5797
# Iteration: 3884; Percent complete: 97.1%; Average loss: 2.6591
# Iteration: 3885; Percent complete: 97.1%; Average loss: 2.6348
# Iteration: 3886; Percent complete: 97.2%; Average loss: 2.7381
# Iteration: 3887; Percent complete: 97.2%; Average loss: 2.5891
# Iteration: 3888; Percent complete: 97.2%; Average loss: 2.7573
# Iteration: 3889; Percent complete: 97.2%; Average loss: 2.7039
# Iteration: 3890; Percent complete: 97.2%; Average loss: 2.6796
# Iteration: 3891; Percent complete: 97.3%; Average loss: 2.4625
# Iteration: 3892; Percent complete: 97.3%; Average loss: 2.5774
# Iteration: 3893; Percent complete: 97.3%; Average loss: 2.6020
# Iteration: 3894; Percent complete: 97.4%; Average loss: 2.9038
# Iteration: 3895; Percent complete: 97.4%; Average loss: 2.6017
# Iteration: 3896; Percent complete: 97.4%; Average loss: 2.5203
# Iteration: 3897; Percent complete: 97.4%; Average loss: 2.5996
# Iteration: 3898; Percent complete: 97.5%; Average loss: 2.7756
# Iteration: 3899; Percent complete: 97.5%; Average loss: 2.3413
# Iteration: 3900; Percent complete: 97.5%; Average loss: 2.5217
# Iteration: 3901; Percent complete: 97.5%; Average loss: 2.5784
# Iteration: 3902; Percent complete: 97.5%; Average loss: 2.5133
# Iteration: 3903; Percent complete: 97.6%; Average loss: 2.6262
# Iteration: 3904; Percent complete: 97.6%; Average loss: 2.5642
# Iteration: 3905; Percent complete: 97.6%; Average loss: 2.5907
# Iteration: 3906; Percent complete: 97.7%; Average loss: 2.7388
# Iteration: 3907; Percent complete: 97.7%; Average loss: 2.5251
# Iteration: 3908; Percent complete: 97.7%; Average loss: 2.5982
# Iteration: 3909; Percent complete: 97.7%; Average loss: 2.4094
# Iteration: 3910; Percent complete: 97.8%; Average loss: 2.8100
# Iteration: 3911; Percent complete: 97.8%; Average loss: 2.8895
# Iteration: 3912; Percent complete: 97.8%; Average loss: 2.6336
# Iteration: 3913; Percent complete: 97.8%; Average loss: 2.5849
# Iteration: 3914; Percent complete: 97.9%; Average loss: 2.5543
# Iteration: 3915; Percent complete: 97.9%; Average loss: 2.5139
# Iteration: 3916; Percent complete: 97.9%; Average loss: 2.6948
# Iteration: 3917; Percent complete: 97.9%; Average loss: 2.5828
# Iteration: 3918; Percent complete: 98.0%; Average loss: 2.6453
# Iteration: 3919; Percent complete: 98.0%; Average loss: 2.7589
# Iteration: 3920; Percent complete: 98.0%; Average loss: 2.6906
# Iteration: 3921; Percent complete: 98.0%; Average loss: 2.5996
# Iteration: 3922; Percent complete: 98.0%; Average loss: 2.4688
# Iteration: 3923; Percent complete: 98.1%; Average loss: 2.6376
# Iteration: 3924; Percent complete: 98.1%; Average loss: 2.5619
# Iteration: 3925; Percent complete: 98.1%; Average loss: 2.7804
# Iteration: 3926; Percent complete: 98.2%; Average loss: 2.5373
# Iteration: 3927; Percent complete: 98.2%; Average loss: 2.6349
# Iteration: 3928; Percent complete: 98.2%; Average loss: 2.7157
# Iteration: 3929; Percent complete: 98.2%; Average loss: 2.6709
# Iteration: 3930; Percent complete: 98.2%; Average loss: 2.4855
# Iteration: 3931; Percent complete: 98.3%; Average loss: 2.7068
# Iteration: 3932; Percent complete: 98.3%; Average loss: 2.8219
# Iteration: 3933; Percent complete: 98.3%; Average loss: 2.4690
# Iteration: 3934; Percent complete: 98.4%; Average loss: 2.6723
# Iteration: 3935; Percent complete: 98.4%; Average loss: 2.6012
# Iteration: 3936; Percent complete: 98.4%; Average loss: 2.6031
# Iteration: 3937; Percent complete: 98.4%; Average loss: 2.8254
# Iteration: 3938; Percent complete: 98.5%; Average loss: 2.6201
# Iteration: 3939; Percent complete: 98.5%; Average loss: 2.5387
# Iteration: 3940; Percent complete: 98.5%; Average loss: 2.9408
# Iteration: 3941; Percent complete: 98.5%; Average loss: 2.7437
# Iteration: 3942; Percent complete: 98.6%; Average loss: 2.6361
# Iteration: 3943; Percent complete: 98.6%; Average loss: 2.6396
# Iteration: 3944; Percent complete: 98.6%; Average loss: 2.4497
# Iteration: 3945; Percent complete: 98.6%; Average loss: 2.5611
# Iteration: 3946; Percent complete: 98.7%; Average loss: 2.7168
# Iteration: 3947; Percent complete: 98.7%; Average loss: 2.3905
# Iteration: 3948; Percent complete: 98.7%; Average loss: 2.7780
# Iteration: 3949; Percent complete: 98.7%; Average loss: 2.5527
# Iteration: 3950; Percent complete: 98.8%; Average loss: 2.7308
# Iteration: 3951; Percent complete: 98.8%; Average loss: 2.8380
# Iteration: 3952; Percent complete: 98.8%; Average loss: 2.3526
# Iteration: 3953; Percent complete: 98.8%; Average loss: 2.4740
# Iteration: 3954; Percent complete: 98.9%; Average loss: 2.5769
# Iteration: 3955; Percent complete: 98.9%; Average loss: 2.7121
# Iteration: 3956; Percent complete: 98.9%; Average loss: 2.8113
# Iteration: 3957; Percent complete: 98.9%; Average loss: 2.4661
# Iteration: 3958; Percent complete: 99.0%; Average loss: 2.6246
# Iteration: 3959; Percent complete: 99.0%; Average loss: 2.4951
# Iteration: 3960; Percent complete: 99.0%; Average loss: 2.5851
# Iteration: 3961; Percent complete: 99.0%; Average loss: 2.6951
# Iteration: 3962; Percent complete: 99.1%; Average loss: 2.4232
# Iteration: 3963; Percent complete: 99.1%; Average loss: 2.6085
# Iteration: 3964; Percent complete: 99.1%; Average loss: 2.6366
# Iteration: 3965; Percent complete: 99.1%; Average loss: 2.7581
# Iteration: 3966; Percent complete: 99.2%; Average loss: 2.4765
# Iteration: 3967; Percent complete: 99.2%; Average loss: 2.5684
# Iteration: 3968; Percent complete: 99.2%; Average loss: 2.7255
# Iteration: 3969; Percent complete: 99.2%; Average loss: 2.4705
# Iteration: 3970; Percent complete: 99.2%; Average loss: 2.7403
# Iteration: 3971; Percent complete: 99.3%; Average loss: 2.4451
# Iteration: 3972; Percent complete: 99.3%; Average loss: 2.4927
# Iteration: 3973; Percent complete: 99.3%; Average loss: 2.5826
# Iteration: 3974; Percent complete: 99.4%; Average loss: 2.6426
# Iteration: 3975; Percent complete: 99.4%; Average loss: 2.6118
# Iteration: 3976; Percent complete: 99.4%; Average loss: 2.8118
# Iteration: 3977; Percent complete: 99.4%; Average loss: 2.4457
# Iteration: 3978; Percent complete: 99.5%; Average loss: 2.5210
# Iteration: 3979; Percent complete: 99.5%; Average loss: 2.7334
# Iteration: 3980; Percent complete: 99.5%; Average loss: 2.6242
# Iteration: 3981; Percent complete: 99.5%; Average loss: 2.7667
# Iteration: 3982; Percent complete: 99.6%; Average loss: 2.5449
# Iteration: 3983; Percent complete: 99.6%; Average loss: 2.6533
# Iteration: 3984; Percent complete: 99.6%; Average loss: 2.4278
# Iteration: 3985; Percent complete: 99.6%; Average loss: 2.3551
# Iteration: 3986; Percent complete: 99.7%; Average loss: 2.5795
# Iteration: 3987; Percent complete: 99.7%; Average loss: 2.4096
# Iteration: 3988; Percent complete: 99.7%; Average loss: 2.6470
# Iteration: 3989; Percent complete: 99.7%; Average loss: 2.4837
# Iteration: 3990; Percent complete: 99.8%; Average loss: 2.4386
# Iteration: 3991; Percent complete: 99.8%; Average loss: 2.6927
# Iteration: 3992; Percent complete: 99.8%; Average loss: 2.6591
# Iteration: 3993; Percent complete: 99.8%; Average loss: 2.4732
# Iteration: 3994; Percent complete: 99.9%; Average loss: 2.6229
# Iteration: 3995; Percent complete: 99.9%; Average loss: 2.7150
# Iteration: 3996; Percent complete: 99.9%; Average loss: 2.5014
# Iteration: 3997; Percent complete: 99.9%; Average loss: 2.5830
# Iteration: 3998; Percent complete: 100.0%; Average loss: 2.5788
# Iteration: 3999; Percent complete: 100.0%; Average loss: 2.6128
# Iteration: 4000; Percent complete: 100.0%; Average loss: 2.7619

# %% [markdown]
# #### Run Evaluation
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)
# Begin chatting by uncommenting the line:
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hi
# Bot: hi . . . . . .
# > how are you ?
# Bot: i m fine . . . .
# > are you okay ?
# Bot: i m fine . . . .
# > what are you doing ?
# Bot: i m going to talk to you . !
# > where are you ?
# Bot: i m going to talk to you !
# > how old are you ?
# Bot: i don t know . . .
# > what is your name ?
# Bot: victor frankenstein . your name .
# > my name is yosef
# Bot: no . you re not . yourself
# > can you help me ?
# Bot: sure . . . . . . .
# > thank you
# Bot: you re welcome . me .
# > bye !
# Bot: i m sorry . ! ! !
# > q

# %% [markdown]
# ### Beam Search Decoding

# %% [markdown]
# So far, we used **greedy decoding**, which selects the most likely next token at each step.
# Greedy decoding is fast, but it may miss better full sequences because it commits to local choices.
#
# In this task you will implement **beam search**, as discussed in class.
# Beam search keeps the top-*k* partial hypotheses at each decoding step, ranked by their cumulative log-probability.
#
# **Requirements**
# - Implement `BeamSearchDecoder` similar in interface to `GreedySearchDecoder`.
# - Use beam width `k` (beam size) as a configurable argument.
# - Use **log-probabilities** (sum of log-probs) to score sequences.
# - Stop a hypothesis when it emits `EOS_token` (you may keep completed hypotheses in a separate list).
# - Return the best decoded token sequence (and optionally its scores).

# %%
class BeamSearchDecoder(nn.Module):
    def __init__(self, encoder, decoder, beam_size=5):
        super(BeamSearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.beam_size = beam_size

    def forward(self, input_seq, input_length, max_length):
        device = input_seq.device

        with torch.no_grad():
            # Encode input
            enc_out, enc_hidden = self.encoder(input_seq, input_length)
            dec_hidden0 = enc_hidden[: self.decoder.n_layers]

            # Start token
            start_tok = torch.tensor([SOS_token], device=device, dtype=torch.long)
            start_inp = start_tok[-1].view(1, 1)

            beams = [(start_tok, dec_hidden0, 0.0, start_inp)]
            finished = []

            for _ in range(max_length):
                expanded = []

                for seq, h, score, dec_inp in beams:
                    last = seq[-1].item()

                    # If EOS, keep as finished
                    if last == EOS_token:
                        finished.append((seq, score))
                        continue

                    # One decoder step
                    out_probs, h_next = self.decoder(dec_inp, h, enc_out)

                    logp = torch.log(out_probs.clamp(min=1e-12)).squeeze(0)

                    top_logp, top_idx = torch.topk(logp, k=self.beam_size)

                    for j in range(top_idx.size(0)):
                        nxt_tok = top_idx[j].view(1)
                        nxt_score = score + top_logp[j].item()

                        new_seq = torch.cat([seq, nxt_tok], dim=0)
                        new_inp = nxt_tok.view(1, 1)

                        if nxt_tok.item() == EOS_token:
                            finished.append((new_seq, nxt_score))
                        else:
                            expanded.append((new_seq, h_next, nxt_score, new_inp))

                if not expanded:
                    break

                expanded.sort(key=lambda x: x[2], reverse=True)
                beams = expanded[: self.beam_size]

            # pick best complete if any , else best partial
            if finished:
                finished.sort(key=lambda x: x[1], reverse=True)
                best_seq = finished[0][0]
            else:
                beams.sort(key=lambda x: x[2], reverse=True)
                best_seq = beams[0][0]

            # drop SOS
            if best_seq.numel() > 0 and best_seq[0].item() == SOS_token:
                best_seq = best_seq[1:]

            dummy_scores = torch.zeros(best_seq.size(0), device=device, dtype=torch.float)
            return best_seq, dummy_scores

# %% [markdown]
# Run the following cell and try the **same 10 prompts** with greedy vs. beam search.
# Briefly comment: do you observe differences? When might beam search help, and when might it hurt?

# %%
greedy_searcher = GreedySearchDecoder(encoder, decoder)
beam_searcher = BeamSearchDecoder(encoder, decoder)

evaluateInput(encoder, decoder, greedy_searcher, voc)
evaluateInput(encoder, decoder, beam_searcher, voc)
# Out:
# > hi
# Bot: hi . . . . . .
# > how are you ?
# Bot: i m fine . . . .
# > are you okay ?
# Bot: i m fine . . . .
# > what are you doing ?
# Bot: i m going to talk to you . !
# > what is your name ?
# Bot: victor frankenstein . your name .
# > can you help me ?
# Bot: sure . . . . . . .
# > how old are you ?
# Bot: i don t know . . .
# > where are you ?
# Bot: i m going to talk to you !
# > thank you
# Bot: you re welcome . me .
# > bye
# Bot: i ll be back ! ! !
# > q
# > hi
# Bot: hi .
# > how are you ?
# Bot: fine .
# > are you okay ?
# Bot: i m fine .
# > what are you doing ?
# Bot: nothing .
# > what is your name ?
# Bot: victor frankenstein .
# > can you help me ?
# Bot: sure .
# > how old are you ?
# Bot: twenty five .
# > where are you ?
# Bot: home .
# > thank you
# Bot: you re welcome .
# > bye
# Bot: bye .
# > q

# %% [markdown]
# **Briefly comment: do you observe differences? When might beam search help, and when might it hurt?:**
#
#
# <font color="red">
# Beam search produces more natural, specific, and fluent responses because it considers multiple possible word sequences before choosing the best one. It helps when generating longer or more accurate replies. However, beam search can hurt by favoring very common or “safe” answers, reducing diversity, and it is slower than greedy decoding.
# </font>

# %% [markdown]
# ### Understanding & Reflection Questions

# %% [markdown]
# Answer the following questions in your own words.
# Your answers should demonstrate conceptual understanding rather than
# code-level details.
#
# 1. **Dataset Understanding**
#    What is the *Cornell Movie-Dialogs Corpus*?
#    Describe the type of data it contains and explain how it is used in
#    this assignment to formulate a learning problem.
#    <font color="red">
#    The Cornell Movie-Dialogs Corpus is a dataset of conversational text extracted from movie scripts, containing dialogue exchanges between characters along with their ordering. In this assignment, it is used to create a supervised learning problem by pairing each utterance with the following reply, where the first sentence is treated as the input and the second as the target output. This allows training a sequence-to-sequence model to learn how to generate a response given a preceding line in a conversation.
#    </font>
#
# 2. **Vocabulary Construction**
#    We implemented a custom `Voc` class to manage the vocabulary.
#    What object or mechanism did we use in class (Tutorials 9–10) to obtain similar functionality?
#    Compare the two approaches at a high level.
#    <font color="red">
# In this assignment, we used a custom Voc class to build and manage the vocabulary manually, including word to index mappings and special tokens. In Tutorials 9-10, similar functionality was provided by `torchtext.Field`, which automatically handles tokenization, vocabulary creation, padding, and numericalization. Both approaches convert text into numerical sequences for sequence models, but the custom Voc class gives more direct control, while `torchtext.Field` offers a higher-level and more automated solution.
#    </font>
#
# 3. **Model Architecture**
#    Describe the model architecture used in this assignment *abstractly*.
#    Your answer should explain the roles of the encoder, decoder, and
#    attention mechanism, without referring to specific code details.
#    <font color="red">
# The model uses a sequence-to-sequence architecture with an encoder, a decoder, and an attention mechanism. The encoder reads the input sentence and converts it into a sequence of representations that capture its meaning. The decoder generates the output sentence one word at a time based on what it has generated so far. The attention mechanism allows the decoder to focus on the most relevant parts of the input sentence at each step, rather than relying on a single summary of the entire input. This helps the model handle longer sentences and produce more accurate responses.
#    </font>
# 4. **Input Representation**
#    What is the dimensionality of each input vector in the sequences fed
#    into the model?
#    Which constant in the implementation determines this dimension, and what does it represent?
#    <font color="red">
# Each input word is represented as a dense vector of size hidden_size. This dimension is determined by the constant hidden_size in the model and represents both the word embedding size and the dimensionality of the RNN hidden states.
#    </font>
#
#
# 5. **Batch Construction**
#    How are training batches constructed in this assignment?
#    Explain how variable-length sequences are handled and why padding,
#    masking, and sorting by sequence length are necessary.
#    <font color="red">
#    Training batches are constructed by sampling multiple input target sentence pairs and grouping them into fixed size batches. Since sentences have variable lengths, all sequences in a batch are padded to the length of the longest sequence using a special padding token, which allows them to be stacked into tensors. A corresponding binary mask is created to mark real tokens and ignore padded positions during loss computation, ensuring that padding does not affect learning. In addition, sequences are sorted by decreasing length so that they can be efficiently processed by recurrent networks using packed sequences, which prevents unnecessary computation on padded elements and enables correct handling of variable-length inputs. Together, padding, masking, and length-based sorting allow efficient batching while preserving the true structure of each sequence.
#    </font>
# 6. **Packed Sequences Efficiency**
#    The function `torch.nn.utils.rnn.pack_padded_sequence` improves
#    computational efficiency by removing padding tokens before passing
#    sequences to the RNN.
#
#    Given the following batch of sequences:
#
#     ```
#     [torch.tensor([10]),
#     torch.tensor([1, 2, 3]),
#     torch.tensor([4, 5]),
#     torch.tensor([6, 7, 8, 9])]
#     ```
#
#
#     By what factor does `pack_padded_sequence` reduce the number of inputs
#     processed by the RNN, compared to processing the padded batch directly?
#     Show your reasoning.
#
# <font color="red">
# When the batch is processed with padding, all sequences are padded to the maximum length of 4. Since there are 4 sequences, the RNN processes (4*4 = 16) input steps, including padding tokens.
# The true lengths of the sequences are 1, 3, 2, and 4, which sum to 10 real tokens. When using `pack_padded_sequence`, the padded tokens are removed, so the RNN processes only these 10 inputs.
# This means that 6 out of the original 16 inputs are removed. Therefore, the amount of computation is reduced by (6 / 16 = 37.5%). In other words, packed sequences reduce the RNN’s computation by 37.5% while keeping the same meaningful information.
#
# </font>

# %% [markdown]
# ## Neural Machine Translation with Sequence-to-Sequence Models (35 Points)
#
# In this question, we turn our attention to **Neural Machine Translation (NMT)** — the task of automatically translating sentences from one natural language to another using neural networks.
#
# Machine translation has long been a central problem in artificial intelligence and natural language processing. Early approaches relied on hand-crafted linguistic rules, followed by large-scale **statistical machine translation (SMT)** systems that modeled translation as a probabilistic inference problem over phrase tables and alignment models. While these methods achieved notable success, they required complex pipelines and extensive feature engineering.
#
# The advent of deep learning introduced a fundamentally different paradigm: instead of explicitly modeling alignments and translation rules, we can train a neural network to **directly map a sentence in one language to a sentence in another**. This idea was popularized by the *sequence-to-sequence* framework, where an encoder network reads an input sequence and a decoder network generates an output sequence, one token at a time.
#
# In this question, we study neural machine translation through a classical and instructive architecture: an **encoder–decoder model with recurrent neural networks**. Concretely, we will work with a **Spanish $\to$ English** translation task, where each training example consists of a Spanish source sentence and its corresponding English translation.
#
#
# Throughout the question, we will move step by step from data representation, through model construction, to qualitative and quantitative analysis of translation behavior.

# %% [markdown]
# > Start by Importing Libraries:

# %%
# Import Libraries

import os
import re
import math
import random
import time
from collections import Counter
from dataclasses import dataclass
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Sampler
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %% [markdown]
# ### Data Loading & Preprocessing

# %% [markdown]
# The next step is to load and organize the data that will serve as the foundation for our translation model.
#
# We work with a **Portuguese–English parallel translation dataset derived from TED Talks**, where each example consists of a spoken Portuguese sentence and its corresponding English translation. The dataset contains sentence-level alignments, making it suitable for supervised sequence-to-sequence learning.
#
# Our dataset consists of **paired Portuguese–English sentences**, where each example contains a Portuguese source sentence and its corresponding English translation. Together, these pairs form a **parallel corpus**, which is the standard training format for neural machine translation systems.
#
# The data spans a wide range of sentence lengths, syntactic structures, and semantic content. Some sentence pairs are short and literal, while others involve rephrasing, reordering, or stylistic adaptation between languages. This variability reflects the nature of real-world translation tasks, where a correct translation often depends on meaning rather than surface-level word alignment.
#
# Because both the input and output are **natural language sequences of variable length**, this dataset immediately poses several practical challenges:
# - sentences must be represented in a numerical form,
# - different sentence lengths must be handled efficiently,
# - and the model must learn when to begin and when to stop generating a translation.
#
# Before defining any neural architecture, we therefore begin by
# reformatting the raw sentence pairs into structures that can be consumed by a learning algorithm.
#
# We start by examining a small subset of the data to understand its basic structure.

# %% [markdown]
# > Run the following cells to load the translation dataset:

# %%
# !pip -q install -U tensorflow-datasets

import tensorflow_datasets as tfds

# sanity: make sure the dataset builder exists
print("TFDS version:", tfds.__version__)
print("Has ted_hrlr_translate?", "ted_hrlr_translate" in tfds.list_builders())
# Out:
# TFDS version: 4.9.9
# Has ted_hrlr_translate? True

# %%
# Load Portuguese → English TED Talks data
train_ds = tfds.load("ted_hrlr_translate/pt_to_en", split="train", as_supervised=True)
val_ds   = tfds.load("ted_hrlr_translate/pt_to_en", split="validation", as_supervised=True)
test_ds  = tfds.load("ted_hrlr_translate/pt_to_en", split="test", as_supervised=True)

print(train_ds, val_ds, test_ds)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.2KSOWC_1.0.0/ted_hrlr_translate-tra…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.2KSOWC_1.0.0/ted_hrlr_translate-val…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/incomplete.2KSOWC_1.0.0/ted_hrlr_translate-tes…
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0. Subsequent calls will reuse this data.
# <_PrefetchDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None))> <_PrefetchDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None))> <_PrefetchDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None))>

# %% [markdown]
# For convenience, the dataset is loaded using **TensorFlow Datasets**.
# However, all subsequent preprocessing, modeling, and training steps in
# this question are implemented entirely in **PyTorch**.
#
# We therefore begin by converting the TensorFlow tensors into standard
# Python lists that can be easily manipulated and later transformed into
# PyTorch tensors.

# %%
def tfds_to_lists(ds, max_examples=None):
    src, tgt = [], []
    for i, (s, t) in enumerate(tfds.as_numpy(ds)):
        src.append(s.decode("utf-8"))
        tgt.append(t.decode("utf-8"))
        if max_examples is not None and i + 1 >= max_examples:
            break
    return src, tgt

# Limit sizes to keep training manageable
MAX_TRAIN = 60000
MAX_VAL   = 2000
MAX_TEST  = 2000

train_pt, train_en = tfds_to_lists(train_ds, MAX_TRAIN)
val_pt,   val_en   = tfds_to_lists(val_ds,   MAX_VAL)
test_pt,  test_en  = tfds_to_lists(test_ds,  MAX_TEST)

print("Train:", len(train_pt))
print("Val:", len(val_pt))
print("Test:", len(test_pt))
# Out:
# Train: 51785
# Val: 1193
# Test: 1803

# %% [markdown]
# As a sanity check, we will also print a small number of paired sentences
# to inspect the raw Portuguese–English data.

# %%
for i in range(5):
    print("PT:", train_pt[i])
    print("EN:", train_en[i])
    print("-" * 60)
# Out:
# PT: e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a serendipidade .
# EN: and when you improve searchability , you actually take away the one advantage of print , which is serendipity .
# ------------------------------------------------------------
# PT: mas e se estes fatores fossem ativos ?
# EN: but what if it were active ?
# ------------------------------------------------------------
# PT: mas eles não tinham a curiosidade de me testar .
# EN: but they did n't test for curiosity .
# ------------------------------------------------------------
# PT: e esta rebeldia consciente é a razão pela qual eu , como agnóstica , posso ainda ter fé .
# EN: and this conscious defiance is why i , as an agnostic , can still have faith .
# ------------------------------------------------------------
# PT: `` `` '' podem usar tudo sobre a mesa no meu corpo . ''
# EN: you can use everything on the table on me .
# ------------------------------------------------------------

# %% [markdown]
# #### Tokenization

# %% [markdown]
# As discussed in class, neural networks do not operate directly on raw
# text. In order to process a sentence with a neural model, we must first
# convert it into a numerical representation.
#
# The standard approach is to represent each sentence as a sequence of
# **tokens**, where each token corresponds to a word drawn from a fixed
# vocabulary. Each word is then mapped to a unique integer index, so that a
# sentence can be viewed as a sequence of integers rather than a sequence
# of strings.
#
# In a translation setting, this process must be carried out **separately**
# for the source language (Portuguese) and the target language (English),
# since the two languages have distinct vocabularies and linguistic
# structure.
#
# As we have seen, practical sequence models also rely on a small number of
# **special tokens** that encode structural information:
# - a padding token, used to align sequences of different lengths,
# - a token marking the beginning of a target sentence,
# - a token marking the end of a target sentence,
# - and a token representing unknown or rare words.
#
# These tokens allow the model to distinguish between meaningful content
# and structural boundaries, and will play an important role throughout
# the translation pipeline.
#
# We therefore begin by explicitly defining these special tokens and
# setting up the basic machinery needed to map text sequences into
# numerical form.

# %% [markdown]
# In this part, you will implement tokenization - the machinery that converts raw text sentences into sequences of integer indices.
#
# Specifically, you should:
# - define a simple tokenization scheme,
# - build separate vocabularies for Portuguese and English,
# - reserve indices for special tokens (`<pad>`, `<unk>`, `<bos>`, `<eos>`),
# - and implement methods for encoding sentences as index sequences and
#   decoding them back to text.

# %%
# Reuse special tokens defined earlier
PAD_TOKEN = "<pad>"
UNK_TOKEN = "<unk>"
BOS_TOKEN = "<bos>"
EOS_TOKEN = "<eos>"

SPECIAL_TOKENS = [PAD_TOKEN, UNK_TOKEN, BOS_TOKEN, EOS_TOKEN]

def tokenize(sentence: str):
    return sentence.strip().split()


class Vocabulary:
    def __init__(self, sentences, min_freq=2):
        """
        sentences: list of raw text sentences
        min_freq : minimum frequency for a word to be included
        """
        counter = Counter()
        for sent in sentences:
            counter.update(tokenize(sent))

        # Initialize vocab with special tokens
        self.itos = list(SPECIAL_TOKENS)
        self.stoi = {tok: i for i, tok in enumerate(self.itos)}

        # Add frequent words
        for word, freq in counter.items():
            if freq >= min_freq and word not in self.stoi:
                self.stoi[word] = len(self.itos)
                self.itos.append(word)

    def encode(self, sentence, add_bos=False, add_eos=False):
        tokens = tokenize(sentence)
        ids = [self.stoi.get(tok, self.stoi[UNK_TOKEN]) for tok in tokens]

        if add_bos:
            ids = [self.stoi[BOS_TOKEN]] + ids
        if add_eos:
            ids = ids + [self.stoi[EOS_TOKEN]]

        return ids

    def decode(self, ids):
        words = []
        for idx in ids:
            word = self.itos[idx]
            if word in {BOS_TOKEN, PAD_TOKEN}:
                continue
            if word == EOS_TOKEN:
                break
            words.append(word)
        return " ".join(words)

    def __len__(self):
        return len(self.itos)


# Build vocabularies
pt_vocab = Vocabulary(train_pt, min_freq=2)
en_vocab = Vocabulary(train_en, min_freq=2)

print("Portuguese vocab size:", len(pt_vocab))
print("English vocab size:", len(en_vocab))
# Out:
# Portuguese vocab size: 21778
# English vocab size: 16517

# %% [markdown]
# Before proceeding, we perform a simple sanity check to verify that the vocabulary and encoding logic behave as expected.
#
# In particular, we encode a sample sentence into a sequence of indices and then decode it back into text. This allows us to confirm that common words are preserved correctly and that rare or unseen words are handled in a consistent manner.

# %%
# Encode and decode a sample sentence
pt_example = train_pt[0]
encoded = pt_vocab.encode(pt_example, add_bos=True, add_eos=True)
decoded = pt_vocab.decode(encoded)

print("Original:", pt_example)
print("Encoded:", encoded[:10], "...")
print("Decoded:", decoded)
# Out:
# Original: e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a serendipidade .
# Encoded: [2, 4, 5, 6, 7, 8, 9, 10, 7, 11] ...
# Decoded: e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a <unk> .

# %% [markdown]
# #### Length-Aware Batching (Bucketing)

# %% [markdown]
# As discussed in class, natural language sentences vary significantly in
# length. When such sequences are grouped into mini-batches, shorter
# sentences must be padded to match the length of the longest sentence in
# the batch.
#
# Excessive padding is computationally wasteful: it increases memory
# usage, slows down training, and introduces artificial tokens that carry
# no semantic information. This issue becomes especially pronounced when a
# batch contains a mix of very short and very long sentences.
#
# A common remedy is **bucketing**, where examples of similar sequence
# lengths are grouped together into the same mini-batch. By batching
# sentences with comparable lengths, we substantially reduce the amount
# of padding required while preserving the efficiency benefits of
# mini-batch training.
#
# In this question, we adopt a BucketIterator-style batching strategy. We
# retain full control over tokenization and vocabulary construction, while
# using length-aware batching to ensure efficient training of our
# sequence-to-sequence model.

# %%
class TranslationDataset(Dataset):
    def __init__(self, src_sentences, tgt_sentences, src_vocab, tgt_vocab):
        assert len(src_sentences) == len(tgt_sentences)
        self.src = src_sentences
        self.tgt = tgt_sentences
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab

    def __len__(self):
        return len(self.src)

    def __getitem__(self, idx):
        src_ids = self.src_vocab.encode(self.src[idx])
        tgt_ids = self.tgt_vocab.encode(self.tgt[idx], add_bos=True, add_eos=True)
        return src_ids, tgt_ids

def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    src_lens = torch.tensor([len(x) for x in src_batch], dtype=torch.long)
    tgt_lens = torch.tensor([len(x) for x in tgt_batch], dtype=torch.long)

    src_pad = pad_sequence(
        [torch.tensor(x, dtype=torch.long) for x in src_batch],
        batch_first=True,
        padding_value=pt_vocab.stoi[PAD_TOKEN]
    )
    tgt_pad = pad_sequence(
        [torch.tensor(x, dtype=torch.long) for x in tgt_batch],
        batch_first=True,
        padding_value=en_vocab.stoi[PAD_TOKEN]
    )

    return src_pad, src_lens, tgt_pad, tgt_lens

class BucketBatchSampler(Sampler):
    def __init__(self, lengths, batch_size, bucket_size=2048, shuffle=True, drop_last=False):
        self.lengths = np.asarray(lengths)
        self.batch_size = batch_size
        self.bucket_size = bucket_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.indices = np.arange(len(self.lengths))

    def __iter__(self):
        idxs = self.indices.copy()
        if self.shuffle:
            np.random.shuffle(idxs)

        for i in range(0, len(idxs), self.bucket_size):
            bucket = idxs[i:i + self.bucket_size]
            bucket = bucket[np.argsort(self.lengths[bucket])]

            for j in range(0, len(bucket), self.batch_size):
                batch = bucket[j:j + self.batch_size]
                if self.drop_last and len(batch) < self.batch_size:
                    continue
                yield batch.tolist()

    def __len__(self):
        n = len(self.indices) // self.batch_size
        if not self.drop_last and len(self.indices) % self.batch_size != 0:
            n += 1
        return n

train_dataset = TranslationDataset(train_pt, train_en, pt_vocab, en_vocab)
val_dataset   = TranslationDataset(val_pt,   val_en,   pt_vocab, en_vocab)

train_src_lengths = [len(pt_vocab.encode(s)) for s in train_pt]
val_src_lengths   = [len(pt_vocab.encode(s)) for s in val_pt]

BATCH_SIZE = 16  # You may experiment with other batch sizes

train_sampler = BucketBatchSampler(train_src_lengths, batch_size=BATCH_SIZE, bucket_size=2048, shuffle=True)
val_sampler   = BucketBatchSampler(val_src_lengths,   batch_size=BATCH_SIZE, bucket_size=2048, shuffle=False)

train_loader = DataLoader(train_dataset, batch_sampler=train_sampler, collate_fn=collate_fn)
val_loader   = DataLoader(val_dataset,   batch_sampler=val_sampler,   collate_fn=collate_fn)

print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))
# Out:
# Train batches: 3237
# Val batches: 75

# %% [markdown]
# Before introducing any neural model, we verify that batching behaves as
# expected.
#
# In particular, we check that:
# - sequences are padded correctly,
# - padding uses the `<pad>` token,
# - and the reported sequence lengths match the unpadded data.

# %%
src_pad, src_lens, tgt_pad, tgt_lens = next(iter(train_loader))

print("Source batch shape:", src_pad.shape)
print("Target batch shape:", tgt_pad.shape)
print("Source lengths (first 5):", src_lens[:5].tolist())
print("Target lengths (first 5):", tgt_lens[:5].tolist())
# Out:
# Source batch shape: torch.Size([16, 2])
# Target batch shape: torch.Size([16, 7])
# Source lengths (first 5): [2, 2, 2, 2, 2]
# Target lengths (first 5): [6, 5, 5, 7, 4]

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# We now describe the complete neural machine translation model that we will implement in this question.
#
# Our system follows the classical **sequence-to-sequence (Seq2Seq)** framework with attention. The model consists of an **encoder** that reads a source sentence in Portuguese and a **decoder** that generates an English translation one token at a time. An **attention mechanism** connects the two, allowing the decoder to selectively focus on different parts of the source sentence during generation.
#
# The figure below illustrates the model at a single decoding timestep.
# The encoder processes the entire source sentence and produces a sequence of hidden states. At each decoding step, the decoder computes attention weights over these encoder states, forms a context vector, and combines it with its current hidden state to predict the next target word.
#
# In the remainder of this question, we will implement this model hierarchically, breaking it down into the following components.

# %% [markdown]
# ![Model Architecture](https://raw.githubusercontent.com/NaamanKopty/Deep-Learning-Course/main/HW3/model_architecture.png)

# %% [markdown]
# #### Encoder

# %% [markdown]
# In this part, you will implement the **encoder**, which reads a Portuguese source sentence
# and produces contextual hidden representations for each source token.
#
# **What to define (layers):**
# 1. **Source embedding**
#    - An embedding layer that maps token indices to vectors:
#      - input: `(B, T_src)` integer token ids
#      - output: `(B, T_src, E)` embeddings
#    - Make sure the `<pad>` token uses `padding_idx` so it does not get trained as a normal token.
#
# 2. **Bidirectional LSTM**
#    - A 1-layer bidirectional LSTM that processes the embedded sequence.
#    - Use packed sequences (with `src_lens`) so the LSTM does not waste computation on padding.
#    - It should output encoder hidden states:
#      - `enc_hiddens`: `(B, T_src, 2H)`  (because bidirectional)
#
# 3. **Dropout**
#    - Apply dropout to embeddings (and/or to the LSTM outputs) for regularization.
#
# **Forward input:**
# - `src_pad`: padded source batch of shape `(B, T_src)`
# - `src_lens`: true lengths of shape `(B,)`
#
# **Forward output:**
# - `enc_hiddens`: `(B, T_src, 2H)`
# - raw final states `(h_n, c_n)` from the BiLSTM:
#   - each of shape `(2, B, H)` (forward + backward)

# %%
class EncoderBiLSTM(nn.Module):
    def __init__(self, src_vocab_size, emb_dim, hidden_dim, pad_idx, dropout=0.1):
        # TODO: Implement
        super().__init__()
        self.embedding = nn.Embedding(src_vocab_size, emb_dim, padding_idx=pad_idx)
        self.lstm = nn.LSTM(emb_dim, hidden_dim, num_layers=1, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(dropout)


    def forward(self, src_pad, src_lens):
        # TODO: Implement
        embedded = self.dropout(self.embedding(src_pad))
        packed_input = pack_padded_sequence(embedded, src_lens.cpu(), batch_first=True, enforce_sorted=False)
        packed_output, (h_n, c_n) = self.lstm(packed_input)
        enc_hiddens, _ = pad_packed_sequence(packed_output, batch_first=True)
        return enc_hiddens, (h_n, c_n)

# %% [markdown]
# #### Attention Mechanism

# %% [markdown]
# In this part, we implement the **attention mechanism** that connects the decoder to the encoder.
#
# At each decoding timestep, the decoder has a hidden state `h_t` of shape `(B, H)`.
# The encoder produced a sequence of hidden states `enc_hiddens` of shape `(B, T_src, 2H)`.
#
# We compute a relevance score between `h_t` and every encoder state, normalize these scores with a softmax to obtain attention weights over the source positions, and then compute a **context vector** as a weighted sum of encoder states.
#
# Because the encoder states have dimension `2H` while the decoder state has dimension `H`, we first project encoder states to dimension `H` so that the dot product is well-defined.
#
# Padding positions in the source should not receive attention, so we apply a mask based on `src_lens`.

# %%
class DotProductAttention(nn.Module):
    def __init__(self, hidden_dim):
        # TODO: Implement
        super().__init__()
        self.W = nn.Linear(2 * hidden_dim, hidden_dim)

    def forward(self, dec_h, enc_hiddens, src_lens):
        # TODO: Implement

        batch_size, max_src_len, _ = enc_hiddens.size()

        enc_proj = self.W(enc_hiddens)

        # Compute attention scores
        scores = torch.bmm(dec_h, enc_proj.transpose(1, 2))

        # Create mask to ignore padding positions in the source
        device = enc_hiddens.device
        mask = torch.arange(max_src_len, device=device).unsqueeze(0) < src_lens.to(device).unsqueeze(1)
        mask = mask.unsqueeze(1)

        # Apply mask before softmax
        scores = scores.masked_fill(~mask, -1e9)

        # Normalize scores into attention weights
        attn_weights = F.softmax(scores, dim=-1)

        # Compute context vectors as weighted sum of encoder states
        context = torch.bmm(attn_weights, enc_hiddens)

        return context, attn_weights

# %% [markdown]
# #### Decoder

# %% [markdown]
# We now implement the **decoder**, which generates the English sentence autoregressively.
#
# During training we use **teacher forcing**:
# - the decoder input at time `t` is the *ground-truth* target token at time `t`
# - the model predicts the token at time `t+1`
#
# Before decoding begins, the decoder must be provided with an **initial hidden state** and **initial cell state**. Our encoder is a *bidirectional* LSTM, so its final states
# come from two directions (forward and backward). The decoder, however, is a *unidirectional* LSTM and therefore expects a single initial hidden/cell state.
#
# To bridge this mismatch, we define a small **decoder initializer** module that:
# 1. Takes the encoder’s final forward and backward states,
# 2. Concatenates them into a `(B, 2H)` vector,
# 3. Projects them to `(B, H)` to obtain the decoder’s initial hidden and cell states.
#
# Once initialized, decoding proceeds as follows:
# 1. Embed the input target tokens (excluding the last token).
# 2. Run a unidirectional LSTM to update the decoder hidden state at each timestep.
# 3. Use attention to compute a context vector from the encoder hidden states.
# 4. Combine the decoder hidden state and context vector to form an **attentional vector** that will later be mapped to vocabulary logits.
#
# The decoder returns a sequence of attentional vectors of shape `(B, T_tgt-1, H)`.

# %%
class DecoderInit(nn.Module):
    """
    Projects final BiLSTM encoder states -> initial UniLSTM decoder states.

    Input:
      h_n, c_n: (2, B, H)  (forward + backward)
    Output:
      h0_dec, c0_dec: (B, H)
    """
    def __init__(self, hidden_dim):
        # TODO: Implement
        super().__init__()
        self.h_n = nn.Linear(2 * hidden_dim, hidden_dim)
        self.c_n = nn.Linear(2 * hidden_dim, hidden_dim)


    def forward(self, h_n, c_n):
        # TODO: Implement
        h_concat = torch.cat((h_n[0], h_n[1]), dim=-1)
        c_concat = torch.cat((c_n[0], c_n[1]), dim=-1)
        h0_dec = torch.tanh(self.h_n(h_concat))
        c0_dec = torch.tanh(self.c_n(c_concat))
        return h0_dec.unsqueeze(0), c0_dec.unsqueeze(0)

# %%
class Decoder(nn.Module):
    def __init__(self, tgt_vocab_size, emb_dim, hidden_dim, pad_idx, dropout=0.1):
        # TODO: Implement
        super().__init__()
        self.embedding = nn.Embedding(tgt_vocab_size, emb_dim, padding_idx=pad_idx)
        self.lstm = nn.LSTM(emb_dim, hidden_dim, batch_first=True)
        self.attention = DotProductAttention(hidden_dim)
        self.combine_proj = nn.Linear(3 * hidden_dim, hidden_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, tgt_pad, dec_init_state, enc_hiddens, src_lens):
        """
        tgt_pad:       (B, T_tgt) includes <bos> ... <eos>
        dec_init_state: (h0_dec, c0_dec) each (B, H)
        enc_hiddens:   (B, T_src, 2H)
        src_lens:      (B,)

        returns:
          attn_vecs: (B, T_tgt-1, H)
        """
        # TODO: Implement

        embedded = self.dropout(self.embedding(tgt_pad[:, :-1]))
        outputs, _ = self.lstm(embedded, dec_init_state)
        context, _ = self.attention(outputs, enc_hiddens, src_lens)
        combined = torch.cat((outputs, context), dim=-1)
        attn_vecs = torch.tanh(self.combine_proj(combined))

        return attn_vecs

# %% [markdown]
# #### Output Projection

# %% [markdown]
# At each decoding timestep, the decoder produces an attentional vector of shape `(B, H)`.
# This vector is a continuous representation, but the task requires predicting a discrete token from the target vocabulary.
#
# We therefore apply a learned linear transformation that maps:
# - from hidden dimension `H`
# - to target vocabulary size `|V_tgt|`
#
# This produces **logits** (unnormalized scores) of shape `(B, T_tgt-1, |V_tgt|)`.
# During training, these logits are used with the cross-entropy loss (while ignoring `<pad>` tokens).

# %%
class OutputProjection(nn.Module):
    def __init__(self, hidden_dim, tgt_vocab_size):
        super().__init__()
        # TODO: Implement
        self.proj = nn.Linear(hidden_dim, tgt_vocab_size)

    def forward(self, attn_vecs):
        """
        attn_vecs: (B, T, H)
        returns:
          logits: (B, T, |V_tgt|)
        """
        return self.proj(attn_vecs)

# %% [markdown]
# #### Full Model Definition

# %% [markdown]
# At this stage, all individual components of the translation model have been implemented: the encoder, the decoder initialization, the decoder with attention, and the output projection.
#
# The full translation model simply **connects these components into a single forward computation**. It does not introduce any new architectural ideas; rather, it defines how data flows through the model during training.
#
# Concretely, the full model performs the following steps:
# 1. Encode the source sentence using the encoder to obtain encoder hidden states.
# 2. Use the final encoder states to initialize the decoder’s hidden and cell states.
# 3. Run the decoder with attention over the encoder states to produce a sequence of decoder representations.
# 4. Apply the output projection to map decoder representations to vocabulary logits.
#
# The model’s forward method returns the unnormalized logits for all target
# positions, which will later be used to compute the training loss.

# %%
class Seq2SeqNMT(nn.Module):
    def __init__(self, encoder, decoder, dec_init, out_proj):
        # TODO: Implement
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.dec_init = dec_init
        self.out_proj = out_proj

    def forward(self, src_pad, src_lens, tgt_pad):
        # TODO: Implement
        enc_hiddens, (h_n, c_n) = self.encoder(src_pad, src_lens)
        h0_dec, c0_dec = self.dec_init(h_n, c_n)
        attn_vecs = self.decoder(tgt_pad, (h0_dec, c0_dec), enc_hiddens, src_lens)
        logits = self.out_proj(attn_vecs)
        return logits

# %% [markdown]
# ### Training

# %% [markdown]
# We now train our neural machine translation model end-to-end.
#
# The model is trained for **25 epochs** using the **Adam** optimizer. The training objective is **token-level cross-entropy loss**, computed over the target sequence under **teacher forcing**. Padding tokens (`<pad>`) do not correspond to real words and are therefore ignored when computing the loss.
#
# After each training epoch, the model is evaluated on a held-out **validation set** (without updating parameters). We record:
# - the average **training loss per token**
# - the average **validation loss per token**
#
# Monitoring both quantities allows us to track learning progress and identify potential overfitting.
#
# Finally, we plot the training and validation loss curves as a function of epoch. Both curves should appear on the same graph for comparison.

# %%
# train one epoch
def train_model(model, train_loader, optimizer, loss_func, pad_idx_tgt):
    model.train()
    total_loss = 0.0
    total_tokens = 0

    for src_pad, src_lens, tgt_pad, tgt_lens in tqdm(train_loader):
        src_pad, tgt_pad = src_pad.to(device), tgt_pad.to(device)
        src_lens = src_lens.cpu()

        optimizer.zero_grad()

        logits = model(src_pad, src_lens, tgt_pad)
        targets = tgt_pad[:, 1:]

        loss = loss_func(logits.reshape(-1, logits.size(-1)), targets.reshape(-1))
        loss.backward()
        optimizer.step()

        num_tokens = (targets != pad_idx_tgt).sum().item()
        total_loss += loss.item() * num_tokens
        total_tokens += num_tokens

    return total_loss / max(total_tokens, 1)


# validate one epoch
def eval_model(model, val_loader, loss_func, pad_idx_tgt):
    model.eval()
    total_loss = 0.0
    total_tokens = 0

    with torch.no_grad():
        for src_pad, src_lens, tgt_pad, tgt_lens in val_loader:
            src_pad, tgt_pad = src_pad.to(device), tgt_pad.to(device)
            src_lens = src_lens.cpu()

            logits = model(src_pad, src_lens, tgt_pad)
            targets = tgt_pad[:, 1:]

            loss = loss_func(logits.reshape(-1, logits.size(-1)), targets.reshape(-1))

            num_tokens = (targets != pad_idx_tgt).sum().item()
            total_loss += loss.item() * num_tokens
            total_tokens += num_tokens

    return total_loss / max(total_tokens, 1)


def visluaize_losses(train_losses, val_losses):
  plt.figure(figsize=(10, 5))
  plt.plot(train_losses, label='Training Loss')
  plt.plot(val_losses, label='Validation Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.title('Training and Validation Loss Curves')
  plt.legend()
  plt.show()

# %%
NUM_EPOCHS = 25
HID_DIM = 128
EMB_DIM = 64
pad_idx_src = pt_vocab.stoi[PAD_TOKEN]
pad_idx_tgt = en_vocab.stoi[PAD_TOKEN]

encoder = EncoderBiLSTM(len(pt_vocab), EMB_DIM, HID_DIM, pad_idx_src).to(device)
dec_init = DecoderInit(HID_DIM).to(device)
decoder = Decoder(len(en_vocab), EMB_DIM, HID_DIM, pad_idx_tgt).to(device)
out_proj = OutputProjection(HID_DIM, len(en_vocab)).to(device)
model = Seq2SeqNMT(encoder, decoder, dec_init, out_proj).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)

criterion = nn.CrossEntropyLoss(ignore_index=pad_idx_tgt)


train_losses, val_losses = [], []
for epoch in range(NUM_EPOCHS):
  train_loss = train_model(model, train_loader, optimizer, criterion, pad_idx_tgt)
  val_loss = eval_model(model, val_loader, criterion, pad_idx_tgt)
  train_losses.append(train_loss)
  val_losses.append(val_loss)
  print(f"Epoch [{epoch+1}/{NUM_EPOCHS}]: Train Loss = {train_loss:.4f}, Val Loss = {val_loss:.4f}")

visluaize_losses(train_losses, val_losses)
# Out:
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [1/25]: Train Loss = 5.2404, Val Loss = 4.3797
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [2/25]: Train Loss = 4.1977, Val Loss = 3.7496
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [3/25]: Train Loss = 3.6821, Val Loss = 3.5224
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [4/25]: Train Loss = 3.3293, Val Loss = 3.1538
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [5/25]: Train Loss = 3.0733, Val Loss = 2.9708
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [6/25]: Train Loss = 2.8758, Val Loss = 2.8578
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [7/25]: Train Loss = 2.7147, Val Loss = 2.7593
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [8/25]: Train Loss = 2.5861, Val Loss = 2.6805
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [9/25]: Train Loss = 2.4777, Val Loss = 2.6322
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [10/25]: Train Loss = 2.3820, Val Loss = 2.6014
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [11/25]: Train Loss = 2.2988, Val Loss = 2.5636
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [12/25]: Train Loss = 2.2249, Val Loss = 2.5969
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [13/25]: Train Loss = 2.1577, Val Loss = 2.5475
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [14/25]: Train Loss = 2.1008, Val Loss = 2.4909
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [15/25]: Train Loss = 2.0454, Val Loss = 2.5429
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [16/25]: Train Loss = 1.9971, Val Loss = 2.4805
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [17/25]: Train Loss = 1.9508, Val Loss = 2.4619
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [18/25]: Train Loss = 1.9102, Val Loss = 2.4482
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [19/25]: Train Loss = 1.8744, Val Loss = 2.4705
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [20/25]: Train Loss = 1.8353, Val Loss = 2.4455
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [21/25]: Train Loss = 1.8022, Val Loss = 2.4474
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [22/25]: Train Loss = 1.7722, Val Loss = 2.4608
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [23/25]: Train Loss = 1.7414, Val Loss = 2.4499
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [24/25]: Train Loss = 1.7138, Val Loss = 2.4521
#   0%|          | 0/3237 [00:00<?, ?it/s]
# Epoch [25/25]: Train Loss = 1.6871, Val Loss = 2.4359

# %% [markdown]
# #### BLEU Evaluation
#
# After training is complete, we evaluate the translation quality of the model using the **BLEU (Bilingual Evaluation Understudy)** score.
#
# BLEU is a **corpus-level** evaluation metric for machine translation. It is computed by comparing a set of model-generated translations (*hypotheses*) against ground-truth translations (*references*). BLEU measures the overlap of n-grams (typically 1- to 4-grams) between the hypotheses and references, and applies a **brevity penalty** to discourage
# overly short translations.
#
# Importantly, BLEU is **not computed during training** and is **not differentiable**. It is used purely for evaluation.
#
# </br>
# </br>
#
# **How BLEU is computed in this question**
#
# 1. The trained model is used to **decode full translations** for each source sentence in the **test set**, using an autoregressive decoding strategy. For this part, use beam search.
# 2. For each test example, the generated translation is treated as the hypothesis, and the ground-truth English sentence is treated as the reference.
# 3. The BLEU score is computed over the entire test set (corpus-level BLEU), and the final BLEU score is reported.
#
#
# **Implement a BLEU evaluation routine** that decodes translations for the test set using beam search and computes the corpus-level BLEU score against the reference translations.
#
# > You may use your implementation of beam search from Q1.

# %%
class BeamSearchDecoderQ2(nn.Module):
    def __init__(self, encoder, decoder, dec_init, out_proj, beam_size=5, max_len=50):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.dec_init = dec_init
        self.out_proj = out_proj
        self.beam_size = beam_size
        self.max_len = max_len
        self.device = next(encoder.parameters()).device

    def forward(self, input_seq, input_length, max_length=None):
        if max_length is None:
            max_length = self.max_len

        enc_hiddens, encoder_hidden = self.encoder(input_seq, input_length)

        h0_dec, c0_dec = self.dec_init(encoder_hidden[0], encoder_hidden[1])
        decoder_hidden = (h0_dec, c0_dec)

        start_token = en_vocab.stoi[BOS_TOKEN]
        eos_token = en_vocab.stoi[EOS_TOKEN]

        beams = [(0.0, [start_token], decoder_hidden)]

        for _ in range(max_length):
            new_beams = []

            for score, tokens, last_hidden in beams:
                if tokens[-1] == eos_token:
                    new_beams.append((score, tokens, last_hidden))
                    continue

                current_input = torch.tensor([[tokens[-1]]], device=self.device)

                embedded = self.decoder.embedding(current_input)
                rnn_output, hidden = self.decoder.lstm(embedded, last_hidden)
                h_t = rnn_output[:, 0, :]

                context, _ = self.decoder.attention(h_t.unsqueeze(1), enc_hiddens, input_length)
                context = context.squeeze(1)

                combined = torch.cat((h_t, context), dim=-1)

                attn_vec = torch.tanh(self.decoder.combine_proj(combined))

                logits = self.out_proj(attn_vec)
                log_probs = F.log_softmax(logits, dim=-1)

                topk_probs, topk_ids = log_probs.topk(self.beam_size)

                for i in range(self.beam_size):
                    next_score = score + topk_probs[0, i].item()
                    next_tokens = tokens + [topk_ids[0, i].item()]
                    new_beams.append((next_score, next_tokens, hidden))

            new_beams.sort(key=lambda x: x[0], reverse=True)
            beams = new_beams[:self.beam_size]

            if all(b[1][-1] == eos_token for b in beams):
                break

        best_score, best_tokens, _ = beams[0]
        return torch.tensor(best_tokens), torch.tensor([best_score])

# %%
# Helper to extract n-grams from a list of tokens.
def get_ngrams(tokens, n):
    return [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def calculate_bleu(references, hypotheses, max_n=4):
    p_ns = []
    for n in range(1, max_n + 1):
        total_matches = 0
        total_hyp_ngrams = 0

        for ref_list, hyp in zip(references, hypotheses):
            hyp_ngrams = get_ngrams(hyp, n)
            total_hyp_ngrams += len(hyp_ngrams)

            if not hyp_ngrams:
                continue

            hyp_counts = Counter(hyp_ngrams)
            max_ref_counts = Counter()
            for ref in ref_list:
                max_ref_counts |= Counter(get_ngrams(ref, n))

            for ngram, count in hyp_counts.items():
                total_matches += min(count, max_ref_counts[ngram])

        if total_hyp_ngrams == 0 or total_matches == 0:
            p_ns.append(0)
        else:
            p_ns.append(total_matches / total_hyp_ngrams)

    if any(p == 0 for p in p_ns):
        return 0.0

    score = math.exp(sum(math.log(p) for p in p_ns) / max_n)

    c = sum(len(h) for h in hypotheses)
    r = sum(len(ref[0]) for ref in references)

    if c > r:
        bp = 1
    else:
        bp = math.exp(1 - r / c) if c > 0 else 0

    return bp * score

def evaluate_bleu(model, test_loader, en_vocab, beam_size=5, max_len=50):
    model.eval()
    hypotheses = []
    references = []

    beam_searcher = BeamSearchDecoderQ2(
        model.encoder,
        model.decoder,
        model.dec_init,
        model.out_proj,
        beam_size=beam_size,
        max_len=max_len
    )

    with torch.no_grad():
        for src_pad, src_lens, tgt_pad, _ in tqdm(test_loader, desc="Decoding Test Set"):
            src_pad = src_pad.to(device)
            src_lens = src_lens.to("cpu")

            for i in range(src_pad.size(0)):
                single_src = src_pad[i:i+1]
                single_len = src_lens[i:i+1]
                tokens, _ = beam_searcher(single_src, single_len, max_length=max_len)
                hyp_sent = en_vocab.decode(tokens.tolist())
                ref_sent = en_vocab.decode(tgt_pad[i].tolist())
                hypotheses.append(hyp_sent.split())
                references.append([ref_sent.split()])

    score = calculate_bleu(references, hypotheses)
    return score * 100

# %%
test_dataset = TranslationDataset(test_pt, test_en, pt_vocab, en_vocab)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn)

test_bleu_score = evaluate_bleu(model, test_loader, en_vocab)

print(f"Final Model BLEU Score on Test Set: {test_bleu_score:.2f}")
# Out:
# Decoding Test Set:   0%|          | 0/113 [00:00<?, ?it/s]
# Final Model BLEU Score on Test Set: 30.19

# %% [markdown]
# ### Understanding & Reflection Questions

# %% [markdown]
# Answer the following questions in your own words.
# Your answers should demonstrate conceptual understanding rather than
# code-level details.
#
# 1. **Parallel Corpus Understanding**
#    What is a *parallel corpus* in machine translation?
#    In this assignment, what constitutes a single training example, and why is this format appropriate for NMT?
#
# <font color="red">
#
#
# **A parallel corpus in machine translation is a dataset that contains sentence pairs, where each sentence in one language is matched with its translation in another language.
# In this assignment, one training example is made of a source sentence (Portuguese) and its corresponding target sentence (English). This format is suitable for NMT because the model is trained to directly translate one sequence into another. The encoder reads and represents the source sentence, and the decoder learns to produce the matching target sentence, helping the model learn word meanings and sentence structure between the two languages.**
# </font>
#
#
# 2. **Vocabulary & Special Tokens**
#    Which special tokens are required for training and decoding (e.g., `<pad>`, `<unk>`, `<sos>`, `<eos>`)?
#    Explain the role of each token in **both** training (teacher forcing) and inference (decoding).
#
#    <font color="red"> **ANSWER:** </font>
#
#   **The key special tokens are:**
#   - PAD_TOKEN = `<pad>`: padding token
#   - UNK_TOKEN = `<unk>`: unknown word token
#   - BOS_TOKEN = `<bos>`: start of sentence token
#   - EOS_TOKEN = `<eos>`: end of sentence token
#
#    **During training (teacher forcing):**
#    - `<pad>`: used to make all sentences in a batch the same length so they can be processed together.
#    - `<unk>`: replaces rare or unseen words that are not in the vocabulary.
#    - `<bos>`: first input to the decoder to indicate that generation should begin.
#    - `<eos>`: marks the end of the target sentence and tells the model when to stop predicting.
#
#
#    **During inference (decoding):**
#    - `<pad>`: is not generated by the model and is mainly used only for batching.
#    - `<unk>`: may appear if the model encounters concepts it cannot represent.
#    - `<bos>`: is used to start the generation process.
#    - `<eos>`: The decoder predicts tokens step by step until it generates <eos>, which signals completion.
#
#
#
# 3. **Encoder–Decoder Interface**
#    Our encoder is a **bidirectional** LSTM while our decoder is **unidirectional**.
#    Explain why this creates a mismatch in the final states, and how we resolve it to initialize the decoder.
#
#
# <font color="red">
#
#
#    **A bidirectional LSTM encoder produces two final states: one from processing the sentence forward and one from processing it backward. In contrast, the decoder is unidirectional and therefore expects a single initial hidden state and cell state. This creates a mismatch because the encoder provides two directional representations while the decoder can only accept one. To resolve this, the final forward and backward encoder states are first concatenated into a single vector. This combined representation is then passed through a learned linear projection, which maps it to the correct dimensionality expected by the decoder. The result is used as the initial hidden state and cell state of the decoder, allowing decoding to begin with information from both directions of the source sentence.**
# </font>
#
#
# 4. **Attention Mechanism (High-level)**
#    What problem does attention solve in neural machine translation?
#    Describe (in words) how the decoder uses attention at a single timestep to choose which source positions to focus on.
#
#
# <font color="red">
#
#
#    **Attention solves the problem of having to represent the entire source sentence with a single fixed size vector, which is especially difficult for long sentences. Instead of relying on one summary vector, the decoder can focus on different parts of the source sentence at each step. At a given decoding timestep, the decoder compares its current hidden state with all encoder hidden states to measure how relevant each source word is. These relevance scores are turned into attention weights, which are used to compute a weighted sum of the encoder states. This context vector helps the decoder choose the next word, allowing the model to focus on the most important source words at each step.**
# </font>
#
#
#
#
#
# 5. **Training vs. Decoding**
#    During training we use teacher forcing, but at test time the model must generate translations autoregressively.
#    Explain the difference between these two settings, and describe one potential consequence of this mismatch.
#
#
# <font color="red">
#
#
# **During training, we use teacher forcing, meaning the decoder is given the ground truth previous word as input at each timestep. This helps the model learn faster and more stably.
# During decoding (test time), the model must generate translations autoregressively, feeding its own previous predictions back into the decoder.
# A potential consequence of this mismatch is error accumulation: if the model makes an early mistake during decoding, that incorrect token is used as input for future steps, which can lead to increasingly poor predictions later in the sentence.**
# </font>
#
# 6. **BLEU Interpretation**
#    What does BLEU measure at a high level, and why is it computed at the **corpus level** rather than per sentence?
#    Briefly explain how the decoding strategy (greedy vs. beam search) can affect BLEU.
#
#
# <font color="red">
# BLEU measures how similar a machine generated translation is to one or more reference translations, based on n-gram overlap and a brevity penalty. At a high level, it evaluates how well the model captures correct word choices and local phrase structure. BLEU is computed at the corpus level rather than per sentence because individual sentences can have many valid translations, making sentence level BLEU very unstable. Aggregating over a corpus provides a more reliable and meaningful measure of translation quality.
#
#
# How the decoding strategy (greedy vs. beam search) can affect BLEU:
# - Greedy decoding picks the most likely next word at each step. This can lead to a sentence that is locally good but globally not the best translation, so BLEU can be lower.
# - Beam search keeps several best partial translations at the same time and chooses the best full sentence at the end. Because it explores more options, it often produces more accurate and fluent translations, which usually increases BLEU.
# </font>
#
#
# 7. **Length Effects**
#    In practice, how does translation quality tend to change as sentence length increases?
#    Give one reason why longer sentences are harder for sequence-to-sequence models.
#
#    <font color="red">
#
#
# **As sentence length increases, translation quality generally decreases. Longer sentences are harder because they contain more dependencies, require longer term memory, and accumulate more opportunities for error during generation. One key reason sequence to sequence models struggle with long sentences is that the decoder must maintain coherent context over many steps, and small prediction errors can compound over time even with attention mechanisms in place.**
# </font>
